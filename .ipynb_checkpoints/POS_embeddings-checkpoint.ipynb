# %% [markdown]
# ## Embeddings

# %%
import pandas as pd
import numpy as np 

from sklearn.metrics import confusion_matrix

from class_NN import neuralNetwork
from utils import extract_info, get_embeddings

# %%
# insert path to embeddings model here
path = "/Users/alessandrapolimeno/Documents/VU/models/sonar-160.tar"

# %% [markdown]
# ### Load data

# %%
# load training data 
path = "../data/pos_data_train.csv"
with open(path, "r") as infile: 
    train_data = infile.readlines()

# load test data
path = "../data/pos_data_test.csv"
with open(path, "r") as infile: 
    test_data = infile.readlines()

# %%
train_data = train_data[:1000]
test_data = test_data[:100]

# %%
data_all = test_data + train_data # for training the embeddings model on

# %% [markdown]
# ### Extact information

# %%
# get relevant information from datasets 
data_all, tokens, pos_tags, targets = extract_info(data_all)
data_tr, tokens_tr, pos_tags_tr, targets_tr = extract_info(train_data)
data_te, tokens_te, pos_tags_te, targets_te = extract_info(test_data)

# %% [markdown]
# ### Initialize NN

# %%
# number of nodes 
input_nodes = 160
# is the number of the vocabulary (dimensions)
hidden_nodes = 150
output_nodes = 12 # equals number of possible labels 

# learning rate 
learning_rate = 0.3

# create instance of neural network 
nn = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

# %%
print(tokens[:20])
# Out:
# ['dat', 'is', 'in', 'italië', ',', 'spanje', 'of', 'engeland', 'misschien', 'geen', 'probleem', ',', 'maar', 'volgens', "'", 'der', 'kaiser', "'", 'in', 'duitsland']

# %%
# get word embeddings for tokens 
#embeddings_model = get_embeddings(path, tokens)

# %%
file = open(path)
c = 0
for line in file: 
    if c < 10: 
        print(line)
    
        records = line.split()
        if records:
            word = records[0]
            c += 1
            if word in tokens:
                print(word)
# Out:
# Dat;9
#
# is;11
#
# in;8
#
# Italië;6
#
# ,;10
#
# Spanje;6
#
# of;3
#
# Engeland;6
#
# misschien;1
#
# geen;9

# %%
def get_embeddings(embeddings_path, tokens, dimension=160):
    """
    This code was taken and adapted from the following tutorial: 
    https://blog.keras.io/using-pre-trained-word-embeddings-in-a-keras-model.html
    (accessed 24 Jan 2021)
    
    :param path: path to downloaded embeddings 
    :param tokens: list containing all tokens that occur in the data
    :param dimension: default = 160 
    
    :return embeddings_dictionary: dict containing embeddings for each token (key = token, values = embeddings)
    
    """
    
    embeddings_dictionary = dict()
    file = open(embeddings_path)

    for line in file:
        records = line.split()
        if records:
            word = records[0]
            if word in tokens:
                try:
                    vector_dimensions = asarray(records[1:], dtype='float32')
                except:
                    pass
            else: 
                vector_dimensions = [0]*dimension
            embeddings_dictionary[word] = vector_dimensions
    file.close()
    return embeddings_dictionary

# %%
c = 0
if c < 10:
    for emb in embeddings_model: 
        print(emb)
        c += 1
# Out:
# Dat;9
# is;11
# in;8
# Italië;6
# ,;10
# Spanje;6
# of;3
# Engeland;6
# misschien;1
# geen;9
# probleem;6
# maar;3
# volgens;8
# ';10
# Der;6
# Kaiser;6
# Duitsland;6
# wel;1
# .;10
# sectie;6
# Zürich;0
# editie;6
# De;2
# kleine;0
# clubs;6
# waarvan;1
# de;2
# begroting;6
# dikwijls;1
# afhankelijk;0
# van;8
# opleiding;6
# en;3
# transfers;6
# klagen;11
# steen;6
# been;6
# over;8
# dat;9
# voornemen;6
# Andere;9
# zijn;9
# bang;0
# dat;3
# salarissen;6
# straks;1
# helemaal;1
# pan;6
# uitrijzen;11
# auteur;6
# Uefa;6
# Fifa;6
# zijn;11
# bereid;0
# afschaffing;6
# transfervergoeding;6
# te;8
# aanvaarden;11
# als;3
# enkel;9
# geldt;11
# voor;8
# voetballers;6
# ouder;0
# dan;3
# 24;7
# jaar;6
# EU;6
# wil;11
# af;1
# elke;9
# vorm;6
# financiële;0
# schadeloosstelling;6
# publicatie;6
# nog;1
# bescheidenere;0
# competities;6
# zoals;3
# Belgische;0
# durven;11
# daar;1
# niet;1
# eens;1
# aan;1
# denken;11
# Morgen;1
# Europese;0
# wereldvoetbalbond;11
# willen;11
# spelers;6
# 14;7
# maakt;11
# het;9
# interessant;0
# om;3
# blijven;11
# investeren;11
# eigen;9
# talent;6
# Bij;8
# onder;8
# 24;6
# zou;11
# bedingen;11
# een;2
# vergoeding;6
# mogelijk;0
# moeten;11
# besluit;6
# Bosman-arrest;6
# bepaalde;9
# speler;6
# aan;8
# het;2
# einde;6
# contract;6
# transfervrij;6
# was;11
# qua;8
# gevolgen;6
# schaduw;6
# stellen;11
# vrijdag;6
# 1;7
# september;6
# 2000;7
# Algemeen;0
# speciale;0
# task;6
# force;6
# internationale;0
# bond;6
# deed;11
# deze;9
# concessie;6
# poging;6
# plannen;6
# Europese;6
# Commissie;6
# bij;8
# sturen;11
# pagina;6
# Reuters;6
# doen;11
# inzake;8
# Die;9
# bestaande;11
# transfersysteem;6
# aangesloten;11
# landen;6
# op;8
# helling;6
# zetten;11
# Een;2
# voetballer;6
# iedere;9
# werknemer;6
# andere;9
# bedrijfstak;6
# vrij;0
# staan;11
# werkgever;6
# veranderen;11
# Sport;6
# publicatiedatum;0
# Fifa-voorzitter;6
# Sepp;6
# Blatter;6
# die;9
# topoverleg;6
# voetbalbonzen;6
# Zürich;6
# gisteren;1
# voorzat;11
# zei;11
# ook;1
# werkgroep;6
# gaat;11
# aandringen;11
# verbod;6
# aan-;6
# verkoop;6
# achttien;7
# Franz;6
# Beckenbauer;6
# voorzitter;6
# Bayern;6
# München;6
# vrezen;11
# bedragen;6
# 225;7
# miljoen;7
# frank;6
# (;10
# 5,6;7
# euro;1
# );10
# netto;0
# gewoon;0
# worden;11
# Van;8
# Roost;6
# verloor;11
# tegen;8
# Amerikaanse;0
# Osterloh;6
# eerste;7
# set;6
# met;8
# 7;7
# -;10
# 6;7
# 9;7
# won;11
# tweede;7
# 4;7
# moest;11
# daarna;1
# gevolg;6
# hitte;6
# strijd;6
# staken;11
# Lindsay;6
# Davenport;6
# nummer;6
# twee;7
# wereld;6
# had;11
# ronde;6
# US;6
# Open;0
# markt;6
# Kim;6
# Clijsters;6
# Behalve;3
# Monami-Van;6
# grandslamtoernooi;6
# New;6
# York;6
# afgelopen;11
# &;6
# 3;6
# Met;8
# spectaculair;0
# aanvalstennis;6
# leek;6
# verrassing;6
# toernooi;6
# maak;6
# zette;11
# scheve;0
# situatie;6
# echter;1
# recht;6
# door;8
# volgende;11
# sets;6
# telkens;1
# 2;7
# winnen;11
# Pagina;6
# 15;7
# :;10
# haalt;11
# hardere;0
# acties;6
# voorzien;11
# """";10
# Daarvoor;1
# bedrijf;6
# te;1
# onduidelijk;0
# vakbonden;6
# positief;0
# ten;8
# aanzien;6
# eventueel;0
# terug;1
# opstarten;6
# onderneming;6
# bod;6
# LDP;6
# we;9
# voorlopig;0
# Coplo;6
# Het;9
# nooit;1
# vertoonde;11
# hervatten;11
# activiteiten;6
# Patrice;6
# D'Hoop;6
# afgevaardigde;11
# Franstalige;0
# socialistische;0
# FGTB;6
# Voor;8
# werknemers;6
# Vincent;6
# De;6
# Poortere;6
# persona;6
# non;6
# grata;6
# Johan;6
# Corthouts;6
# JCS;6
# Als;3
# curatoren;6
# ons;9
# afslaan;11
# dan;1
# rest;6
# er;1
# alleen;1
# maar;1
# sluiting;6
# terugkeer;6
# aldus;1
# Het;2
# personeel;6
# schuift;11
# hem;9
# verantwoordelijkheid;6
# faillissement;6
# schoenen;6
# Domo-woordvoerder;6
# Erik;6
# heeft;11
# aangekondigd;11
# wachten;11
# beu;0
# zegt;11
# Financiële;6
# Bedrijven;6
# Gisteren;1
# trammelant;11
# poorten;6
# vervoerden;6
# goederen;6
# opbrengst;6
# gebruikt;11
# betaling;6
# personeelsleden;6
# momenteel;0
# slag;6
# handelen;11
# Arbeiders;6
# bezetten;11
# verhinderden;11
# tot;8
# tweemaal;1
# toe;8
# doorgang;6
# aantal;6
# vrachtwagens;6
# arbeiders;6
# stelden;11
# vast;0
# onderdelen;6
# machines;6
# stonden;11
# Domo;6
# vraagt;11
# curatele;6
# weer;1
# op;1
# starten;11
# Vakbonden;6
# spreken;11
# originele;0
# formule;6
# vroegere;0
# baas;6
# eigenaar;6
# Balsan;6
# Anderzijds;1
# blijkt;11
# informatica-;6
# verkoopsafdelingen;6
# LDP's;6
# zusteronderneming;6
# Franse;0
# Châteauroux;6
# werden;11
# ondergebracht;11
# Om;3
# hun;9
# ongenoegen;6
# uiten;11
# zullen;11
# ze;9
# maandag;6
# Kortrijk;6
# Moeskroen;6
# wegen;11
# blokkeren;11
# gebrek;6
# informatie;6
# onduidelijkheid;6
# kansen;6
# overname;6
# kwaad;6
# bloed;6
# Onder;8
# ruim;0
# vijfhonderd;7
# neemt;11
# zenuwachtigheid;6
# Textielbedrijf;11
# failliete;0
# tapijtfabrikant;6
# Louis;6
# opnieuw;1
# Twee;7
# weken;6
# na;8
# kunnen;11
# zekerheid;6
# bepalen;11
# wie;9
# eigendomsrecht;6
# collecties;6
# design;6
# merknaam;6
# bezit;11
# daarin;1
# toestemt;11
# management;6
# voeren;11
# Achteraf;1
# bleek;11
# eigendom;6
# waren;11
# vervoerd;11
# naar;8
# rechtmatige;0
# Heel;1
# wat;9
# conjunctuuranalisten;6
# zien;11
# bewijs;6
# renteverhoging;6
# contraproductief;11
# werkt;11
# economische;0
# groei;6
# Europa;6
# voortijdig;0
# dreigt;11
# stikken;11
# Centrale;6
# Bank;6
# verhoogde;11
# haar;9
# centraal;0
# rentetarief;6
# kwart;6
# procent;6
# 4,5;7
# Bovendien;1
# hogere;0
# rente;6
# in;1
# slagen;11
# inflatie;6
# zwakken;0
# Door;8
# verzwakkende;11
# euro;6
# olie-;6
# importproducten;6
# duurder;0
# Jan;6
# Scheidtweiler;6
# ...;10
# Toch;1
# kon;11
# verhinderen;11
# andermaal;1
# weggleed;11
# --;6
# Scenario;6
# Center;6
# Parcs;6
# krijgt;11
# nieuwe;0
# ECB;6
# ging;11
# ironisch;0
# genoeg;9
# omdat;3
# beteugelen;11
# pagina's;6
# 17;7
# 18;7
# 12;7
# deelnemers;6
# meer;7
# Régis;6
# Wargnier;6
# Stijn;6
# Coninx;6
# regisseurs;6
# Patrick;6
# Doyle;6
# Dirk;6
# Brossé;6
# componisten;6
# T.;6
# spiraal;6
# geweld;6
# vergelding;6
# meer;1
# stoppen;11
# In;8
# film;6
# gebaseerd;11
# bloederigste;6
# gewelddadigste;0
# toneelstukken;6
# William;6
# Shakespeare;6
# speelt;11
# Anthony;6
# Hopkins;6
# rol;6
# Romeinse;0
# generaal;6
# Titus;6
# Andronicus;6
# net;1
# teruggekeerd;11
# veldslag;6
# Gothen;6
# Eigen;9
# berichtgeving;6
# Temmerman;6
# Gent;6
# Cultuur;6
# opener;6
# filmfestival;6
# volledige;0
# festivalprogramma;6
# waarvoor;1
# zo'n;9
# tweehonderd;7
# films;6
# geselecteerd;11
# wordt;11
# 22;7
# bekendgemaakt;11
# Julie;6
# Taymor;6
# werd;11
# eerder;0
# vooral;1
# bekend;0
# Tony-award;6
# bekroonde;11
# musicalversie;6
# Disney-tekenfilm;6
# The;6
# Lion;6
# King;6
# Ze;9
# daarbij;1
# positie;6
# gebruik;6
# wraak;6
# nemen;11
# dochter;6
# Lavinia;6
# Laura;6
# Fraser;6
# slachtoffers;6
# goden;6
# danken;11
# overwinning;6
# oudste;0
# zoon;6
# Tamora;6
# koningin;6
# geofferd;11
# Later;0
# vertolkt;11
# Jessica;6
# Lange;0
# minnares;6
# corrupte;0
# keizer;6
# Saturninus;6
# Alan;6
# Cumming;6
# Op;8
# dinsdag;6
# 10;7
# oktober;6
# fungeert;11
# evenement;6
# Hans;6
# Zimmer;6
# Live;6
# in;6
# Concert;6
# vooropening;6
# loopt;11
# zaterdag;6
# 21;7
# Taymor;1
# Goldenthal;6
# deelnemen;11
# seminarie;6
# rond;8
# filmmuziek;6
# Sint-Pietersabdij;6
# dit;9
# teken;6
# staat;11
# artistieke;0
# relatie;6
# tussen;8
# regisseur;6
# componist;6
# Dit;9
# concert;6
# Kuipke;6
# Sportpaleis;6
# unieke;0
# wereldcreatie;6
# superlatieven;6
# overladen;11
# tevens;1
# controversiële;0
# Shakespeare-verfilming;6
# cineaste;6
# openingsfilm;6
# 27ste;7
# Internationaal;0
# Filmfestival;6
# allereerste;0
# keer;6
# zal;11
# Gladiator;6
# Rainman;6
# Thin;6
# Red;6
# Line;6
# Driving;6
# Miss;6
# Daisy;6
# Peacemaker;6
# True;6
# Romance;6
# Prince;6
# Egypt;6
# uitgebreide;11
# selectie;6
# uit;8
# werk;6
# voorstellen;11
# Zij;9
# zelf;9
# officiële;0
# opening;6
# woensdag;6
# 11;7
# aanwezig;0
# samen;1
# echtgenoot;6
# bekende;0
# filmcomponist;6
# Elliot;6
# muziek;6
# componeerde;11
# Ruud;6
# Goossens;6
# cijfers;6
# zittenblijvers;6
# onderwijsachterstand;11
# heel;1
# minder;7
# Elk;9
# studiegebied;6
# opgedeeld;11
# beroepsprofielen;6
# samenspraak;6
# beroepsleven;6
# opgesteld;11
# bouw;6
# bijvoorbeeld;1
# metselaar;6
# bekister;6
# 5;7
# RG;6
# betekent;11
# afstemming;6
# arbeidsmarkt;6
# algemene;0
# vorming;6
# oog;6
# verloren;11
# klonk;11
# Brussel;6
# Vanaf;8
# begin;6
# volgend;11
# schooljaar;6
# stappen;6
# dertigtal;6
# scholen;6
# modulariseringsproject;6
# Uit;8
# onderzoeken;11
# immers;1
# Vlaams;6
# onderwijs;6
# goed;0
# scoort;11
# kwalitatief;0
# gebied;6
# tegelijkertijd;1
# alle;9
# leerlingen;6
# meekrijgt;11
# Graden;11
# leerjaren;6
# bestaan;11
# modulair;0
# evaluatie;6
# volgt;11
# eind;6
# 2006;7
# 2007;7
# Ook;1
# Centra;6
# Leerlingenbegeleiding;6
# vandaag;1
# Aula;6
# 28;7
# profielen;6
# beurt;6
# modules;6
# Journaal;6
# men;9
# nu;1
# bereiken;11
# leerstof;6
# werken;11
# kortere;0
# tijd;6
# afgewerkt;11
# zo;1
# tussentijdse;0
# succesbeleving;6
# leiden;11
# instantie;6
# vijf;7
# studiegebieden;6
# waarin;1
# systeem;6
# ingevoerd;11
# auto;6
# handel;6
# mechanica-elektriciteit;6
# personenzorg;11
# organisatie;6
# leeraanbod;6
# flexibeler;0
# maken;11
# hoopt;11
# minister;6
# Onderwijs;6
# Marleen;6
# Vanderpoorten;6
# VLD;6
# niet-gekwalificeerden;6
# beroepsonderwijs;6
# dringen;11
# komt;11
# erop;1
# krikken;11
# Twintig;7
# Vlaamse;0
# Beroepssecundair;6
# BSO;6
# vanaf;8
# project;6
# modularisering;6
# kiezen;11
# langer;0
# deelcertificaten;11
# behalen;11
# waarmee;1
# terechtkunnen;11
# stap;6
# herwaardering;6
# waarbij;1
# jongeren;0
# vier;7
# schooljaren;11
# diploma;6
# afgeleverd;11
# krijgen;11
# leidt;11
# vaak;1
# opeenvolging;6
# mislukkingen;6
# echt;0
# vak;6
# wiskunde;6
# grondstoffenleer;6
# bestaan;6
# geïntegreerde;11
# manier;6
# overgebracht;11
# beroepsscholen;6
# opleidingsmodules;6
# Alleen;1
# nauwer;0
# aansluiten;11
# praktische;0
# lessen;6
# internetsector;6
# gebeurde;11
# shake-out;6
# verscheidene;9
# dotcommers;6
# anderen;9
# cash-burn-dood;6
# gered;11
# via;8
# blijft;11
# zeer;1
# moeilijk;0
# potentieel;6
# elk;9
# schatten;11
# Koen;6
# Van;6
# Steene;6
# maximale;0
# verlies;6
# 23,5;7
# Nasdaq-index;6
# laatste;0
# maanden;6
# omgebogen;11
# lichte;0
# winst;6
# +;6
# 2.5;7
# t.o.v.;8
# januari;6
# Winnaars;6
# alvast;1
# bedrijven;6
# CommerceOne;6
# Ariba;6
# knock-out;6
# running;6
# SAP;6
# belangijk;0
# deel;6
# cyberkoek;6
# zich;9
# Robert;6
# Melders;6
# U;9
# kunt;11
# rechtstreeks;0
# beurs;6
# ICG;6
# Internet;6
# Capital;6
# Group;6
# CMGI;6
# kopen;11
# Nochtans;1
# noteren;11
# slechts;1
# handvol;6
# kleppers;6
# topkoersen;6
# Sun;6
# Micro;6
# Oracle;6
# Intel;6
# Eén;6
# ding;6
# hebben;11
# allemaal;9
# gemeen;0
# high;0
# risk;6
# /;10
# potentials;6
# Beide;7
# holdings;6
# geïnvesteerd;11
# waaier;6
# internetbedrijven;6
# geroemde;11
# internetaandelen;6
# tonen;11
# tekenen;6
# pril;0
# herstel;6
# zware;0
# uppercut;6
# april;6
# Vermogensbeheerder;6
# Maertelaere;6
# duidelijk;0
# tegenstelling;6
# koersinzinking;6
# bijna;1
# volledig;0
# verteerd;11
# Gezien;8
# volatiliteit;6
# aandelen;6
# mijden;11
# voorzichtige;0
# huisvaders;6
# tenzij;3
# beperkt;11
# portefeuille;6
# Vele;7
# blue;6
# chips;6
# konden;11
# torenhoge;0
# winstverwachtingen;6
# waarmaken;11
# hiervoor;1
# afgestraft;11
# koersval;6
# vele;7
# internethype;6
# herleiden;11
# zeepbelachtige;0
# proporties;6
# Wilt;11
# u;9
# toch;1
# internettrein;6
# springen;11
# uw;9
# risico;6
# enigszins;1
# spreiden;11
# mandje;6
# internetstocks;0
# technologiesector;6
# exclusief;1
# telecom;1
# al;1
# tijdje;6
# remonte;6
# bezig;0
# Gestolen;7
# auto's;6
# motorpech;0
# bommen;6
# tijdig;0
# afgaan;11
# terroristen;6
# per;8
# abuis;6
# zichzelf;9
# opblazen;11
# hooguit;1
# allerkwetsbaarste;0
# doelwitten;6
# richten;11
# Destijds;1
# meerdere;7
# Spaanse;0
# verzoeken;6
# uitlevering;6
# vanuit;8
# België;6
# ingewilligd;11
# uitleveringsstructuur;6
# zitten;11
# steeds;1
# hinderpalen;6
# Lode;6
# Delputte;6
# Al;1
# winkel;6
# politieke;0
# steun;6
# ETA;6
# vermindert;11
# terwijl;3
# rechtsstaat;6
# sterker;0
# verwacht;11
# samenwerking;6
# Frankrijk;6
# overwonnen;11
# Europees;0
# parlementslid;6
# Javier;6
# Pomés;6
# Ruiz;6
# Volkspartij;6
# EVP;6
# gedeeltelijke;0
# Baskischtalige;6
# regio;6
# Navarra;6
# vertegenwoordigt;11
# escorte;6
# bewaakt;11
# ziet;11
# dodelijke;0
# geklungel;6
# twaalf;7
# maakte;11
# voorbode;6
# verval;6
# niveau;6
# gerechtelijke;0
# coöperatie;6
# gaandeweg;1
# verstevigd;11
# Wilde;11
# Wie;9
# nationaal;0
# internationaal;0
# invloed;6
# moet;11
# eerst;1
# één;11
# eerst;0
# 25;7
# kan;11
# regering;6
# zoveel;7
# geld;6
# uitgeven;11
# Iedereen;9
# delen;11
# vruchten;6
# bloei;6
# jaren;6
# inspanningen;6
# geleverd;11
# overheidsfinanciën;6
# saneren;11
# iedereen;9
# genieten;11
# voorspoed;6
# prestaties;6
# PS-ministers;6
# evalueren;11
# meteen;1
# aanloop;6
# gemeenteraadsverkiezingen;6
# 8;7
# techniek;6
# belastingkrediet;6
# laagste;0
# arbeidsinkomens;6
# rekenen;11
# PS-instemming;6
# pas;1
# effect;6
# Ik;9
# heb;11
# hard;0
# gewerkt;11
# PS;6
# komende;11
# grondig;0
# vrouwen;6
# Zelf;9
# hij;9
# goede;0
# score;6
# halen;11
# thuisbasis;6
# Bergen;6
# burgemeester;6
# socialisten;6
# beperkte;11
# fiscale;0
# autonomie;6
# regio's;6
# Di;6
# Rupo;6
# best;0
# vinden;11
# discussie;6
# vergrijzing;6
# werkloosheidsvallen;6
# bestrijden;11
# laat;11
# aftrek;6
# kinderopvang;6
# verbeteren;11
# PS-voorzitter;6
# Elio;6
# aanvaardt;11
# historisch;0
# moment;6
# land;6
# stelt;11
# gesprek;6
# redactie;6
# verkiezingen;6
# minstens;1
# vorig;0
# gunt;11
# Vlamingen;6
# geheel;6
# bekeken;11
# constructieve;0
# communautaire;0
# sfeer;6
# heerst;11
# Over;8
# verhoging;6
# pensioenleeftijd;6
# praten;11
# al;3
# weet;11
# werkdocument;6
# ontbreekt;11
# iets;9
# kinderen;6
# want;3
# mag;11
# Franstaligen;6
# nadeel;6
# opleveren;11
# hervormingen;6
# doorvoeren;11
# toe;1
# financieel;0
# achteruitgaan;6
# rijkere;0
# Vlaanderen;6
# trekken;11
# belastingen;6
# beduidend;11
# lager;0
# zouden;11
# liggen;11
# partij;6
# overgenomen;11
# sinds;8
# voltijds;1
# generaties;6
# En;3
# niets;9
# mobiliteit;6
# belastingverlaging;6
# Financiën;6
# Didier;6
# Reynders;6
# PRL;6
# voorstelt;11
# deels;1
# instemming;6
# Trouwens;1
# niemand;9
# tijdens;8
# belangrijke;0
# benadeeld;11
# generatie;6
# beschikbare;0
# Zondag;6
# congresseren;11
# Vroeg;11
# hele;0
# problematiek;6
# bekijken;11
# snel;0
# komen;11
# Zilverfonds;6
# om;8
# pensioenen;6
# toekomst;6
# garanderen;11
# forfaitaire;0
# verwerkt;11
# bedrijfsvoorheffing;6
# onmiddellijk;0
# We;9
# duidelijke;0
# visie;6
# eenoudergezinnen;6
# oudere;0
# alleenstaanden;0
# vergeten;11
# najaar;6
# prioriteiten;6
# informatiemaatschappij;6
# werkgelegenheid;6
# aandacht;6
# verschil;6
# Wallonië;6
# gezondheidszorg;6
# jaarlijkse;0
# 3,5;7
# plaats;6
# 2,5;7
# sociale;0
# uitkeringen;6
# drie;7
# gerealiseerd;11
# schiet;11
# over;1
# NMBS;6
# bekendmaking;6
# S;6
# N;7
# durende;11
# speculaties;6
# vestigingen;6
# Peer;6
# Lommel;6
# 1.700;7
# mensen;6
# dienst;6
# 700;7
# vaste;0
# Belga;6
# vasteland;6
# bezit;6
# partijen;6
# daarvoor;1
# gezamenlijke;0
# holding;6
# oprichten;11
# aandeelhouders;6
# mededelingen;6
# bedoeld;11
# bleken;11
# blij;0
# overleg;6
# Britse;0
# DB;6
# Scottish;6
# Newcastle;6
# bezighouden;11
# brouwen;11
# bier;6
# detailhandel;6
# bungalowparken;6
# hoogstwaarschijnlijk;0
# Frans-Duits;6
# media;6
# doken;11
# geregeld;11
# mogelijke;0
# gegadigden;0
# hier;1
# melding;6
# gemaakt;11
# maatschappij;6
# Gran;6
# Dorado;6
# Pierre;6
# et;5
# Vacances;5
# kwam;11
# 1989;7
# handen;6
# N.;6
# stichting;6
# Nederlandse;0
# zakenman;6
# Derksen;6
# huidige;0
# brouwerijgroep;6
# exclusief;0
# gepraat;11
# vakantieonderneming;6
# Partners;6
# investeringsdivisie;6
# Deutsche;6
# aandeel;6
# sloot;11
# 1,5;7
# pond;6
# 461;7
# praat;11
# afstoten;11
# Pontins;6
# keten;6
# vakantiebungalows;6
# enige;0
# gegadigde;6
# Manor;6
# dichtbij;1
# maart;6
# verkocht;11
# 360;7
# pubs;6
# juli;6
# kocht;11
# merendeel;6
# bierbelangen;6
# Kronenbourg;6
# Danone;6
# ontgoocheld;11
# hadden;11
# gehoopt;11
# brouwerijconcern;6
# definitief;0
# vakantieparken;6
# bekendmaken;11
# Toerisme;6
# Blok;6
# ROB-tv;6
# 199;7
# geslaagd;11
# herkansing;6
# kwamen;11
# veel;7
# meisjes;6
# 467;7
# jongens;6
# 264;7
# opdagen;11
# uitnodigen;6
# reeks;6
# debatten;6
# Oost-Brabantse;0
# regionale;0
# omroep;6
# organiseert;11
# aanleiding;6
# gemeente-;6
# provincieraadsverkiezingen;6
# KORT;6
# korte;0
# reportages;6
# uitgezonden;11
# achtergrondinformatie;6
# gemeente;6
# Maar;3
# 80;7
# slaagden;11
# 119;6
# Oorspronkelijk;0
# 851;7
# ingeschreven;11
# toelatingsexamen;6
# 731;7
# namen;6
# augustus;6
# Hoofdredacteur;6
# Veldeman;6
# wou;11
# commentaar;6
# kwijt;0
# interne;0
# beslissing;6
# lijsten;6
# kandidaten;6
# teletekst;6
# verkiezingsuitslagen;6
# Net;1
# ongeveer;1
# toelatingsexamen;11
# studies;6
# tand;6
# arts;6
# hoofdredactie;6
# zopas;1
# beslist;11
# Meer;7
# 500;7
# daardoor;1
# beginnen;11
# studeren;11
# tandarts;6
# slaagpercentage;6
# overeen;1
# examen;6
# Kwart;6
# slaagt;11
# denkt;11
# inkomensgroepen;6
# petroleumfederatie;6
# hoop;6
# afwachting;6
# verwachte;11
# prijsdalingen;6
# opstelt;11
# Minister;6
# Economie;6
# Picqué;6
# liet;11
# weten;11
# overleggen;11
# hoe;1
# overheid;6
# inkomens;6
# helpen;11
# huisbrandolie;6
# betalen;11
# Federaal;0
# Landbouw;6
# Jaak;6
# Gabriëls;6
# visserij;6
# tafel;6
# problemen;6
# veroorzaakt;11
# dure;0
# diesel;6
# lossen;11
# Verder;0
# tijdelijke;0
# opheffing;6
# accijnzen;6
# Cedric;6
# Lagast;6
# Leven;6
# Volgens;8
# vissers;6
# groot;0
# vloot;6
# failliet;0
# gaan;11
# dehoge;0
# dieselprijzen;6
# Werklozen;6
# personen;6
# minimumloon;6
# woning;6
# korting;6
# factuur;6
# Ten;8
# lage;0
# zodat;3
# oliefacturen;6
# oplossing;6
# waarschuwde;11
# vlak;6
# gezocht;11
# aankaarten;6
# informele;0
# landbouwtop;6
# Biarritz;6
# begint;11
# ogenblik;6
# compensatiemaatregel;6
# visserijsector;6
# uitpakt;11
# zie;11
# Na;8
# afloop;6
# ambtgenoot;6
# Vera;6
# Dua;6
# Agalev;6
# mogelijkheid;6
# uitreiken;11
# overbruggingskredieten;6
# bespreken;11
# vroegste;0
# Charles;6
# kondigde;11
# zespuntenplan;6
# betaalbaar;0
# houden;11
# kabinet;6
# federaal;0
# vervangende;11
# heffingen;6
# Luxemburg;6
# Unie;6
# afdwingen;11
# Aangezien;3
# bevoegdheden;6
# Vande;6
# Lanotte;6
# SP;6
# behoort;11
# bestek;6
# armoedebestrijding;6
# gisterenmiddag;1
# kabinetten;6
# dacht;11
# eveneens;1
# ingreep;6
# BTW;6
# nodig;0
# waarschijnlijkheid;6
# week;6
# gebeurt;11
# top;6
# ministers;6
# energiecheques;6
# uitstel;6
# inning;6
# verkeersbelasting;6
# Verscheidene;9
# politici;6
# reageerden;11
# problematische;0
# prijsstijgingen;6
# olieproducten;6
# Hij;9
# raadt;11
# ministerraad;6
# tiental;6
# dagen;6
# geven;11
# winter;6
# slaan;11
# buitenlandse;0
# CL;6
# Kamerlid;6
# Yves;6
# Leterme;6
# CVP;6
# diende;11
# voorstel;6
# binnenkrijgt;11
# stijgende;11
# prijzen;6
# terugschuift;11
# consument;6
# accijnsverlagingen;6
# opgetogen;0
# uit;1
# lijdt;11
# slotte;6
# stelde;11
# om;1
# reiken;11
# Concreet;11
# zes;7
# concrete;0
# zaken;6
# zeggen;11
# voorgesteld;11
# mei;6
# toen;1
# tegenstand;6
# gebotst;11
# Stijgende;11
# brandstofprijzen;6
# schudden;11
# wakker;0
# wagen;6
# gestolen;11
# Servische;0
# Club;6
# Brugge-speler;6
# Milan;6
# Lesnjak;6
# Loppemsestraat;6
# Zedelgem;6
# parket;6
# Mechelen;6
# overgemaakt;11
# Aanleiding;6
# actie;6
# klachten;6
# buurtbewoners;6
# drugsoverlast;6
# zij;9
# durfden;11
# buiten;8
# laten;11
# zegden;11
# Woensdagnacht;1
# politie;6
# rijkswacht;6
# Mortsel;6
# speelplein;6
# Redoute;6
# Edmond;6
# Thieffrylaan;6
# schoongeveegd;1
# dealers;6
# junkies;6
# buurman;6
# ingebroken;11
# ter;8
# beschikking;6
# gesteld;11
# procureur;6
# des;2
# konings;6
# Daar;1
# kredietkaart;6
# bos;6
# autosleutels;6
# meegenomen;11
# achtervolging;6
# ingezet;11
# ontkomen;11
# voertuig;6
# wilden;11
# controleren;11
# snelde;11
# weg;1
# grote;0
# invalswegen;6
# stad;6
# ring;6
# lanen;6
# wegen;6
# Terkamerenbos;6
# dieven;6
# stelen;11
# onlangs;1
# proef;6
# vrijgelaten;11
# gevangenis;6
# strikte;0
# voorwaarde;6
# alles;9
# drugs;6
# onthouden;11
# start;11
# patrouille;0
# onbeschaamdheid;6
# achter;8
# stuur;6
# registreren;11
# totaal;6
# 100;6
# gram;6
# softdrugs;6
# beslag;6
# genomen;11
# plus;3
# gediend;11
# uitvalsbasis;6
# lokaal;6
# groep;6
# chauffeurs;6
# rijden;11
# stoplicht;6
# negeren;11
# roekeloos;0
# verbaliseren;6
# Speelplein;6
# drugsplein;0
# patrouille;6
# vorige;0
# nacht;6
# groene;0
# VW;6
# Golf;6
# achtervolgd;11
# streek;6
# Brugge;6
# kwestie;6
# beelden;6
# overtredingen;6
# beeldscherm;6
# camera;6
# 21-jarige;0
# dealer;6
# Antwerpen;6
# 23;7
# gebruiksdoses;6
# marihuana;6
# zak;6
# rijkswachters;6
# vonden;11
# verdacht;11
# dertig;7
# gecontroleerde;11
# tien;7
# zoomt;11
# agressief;0
# rijgedrag;6
# Dieven;6
# haal;11
# naast;8
# buitgemaakt;11
# Zijn;9
# kompaan;6
# afkomstig;0
# Duffel;6
# negentien;7
# Dagelijks;0
# agenten;6
# anonieme;0
# verkeersassen;6
# rondrijden;11
# digitale;0
# gedrag;6
# vastleggen;11
# patrouilleren;11
# waar;1
# verleden;6
# onbezonnen;6
# rijgedrag;11
# vastgesteld;11
# Huisvesting;6
# Sauwens;6
# wees;11
# persvoorstelling;6
# donderdag;6
# doelstelling;6
# burger;6
# loket;6
# bieden;11
# terechtkan;11
# overheidsinformatie;6
# ambtenaren;6
# socialehuisvestingsmaatschappijen;6
# beschikken;11
# Woonnet;6
# informaticanetwerk;6
# hen;9
# verbindt;11
# centrale;0
# computer;6
# Huisvestingsmaatschapij;6
# VHM;6
# helpt;11
# zoektocht;6
# betrokkenen;11
# typedocumenten;6
# downloaden;11
# relevante;0
# wetgeving;6
# uitwisselen;11
# geoloket;11
# website;6
# biedt;11
# verschillende;9
# rechten;6
# voorverkoop.;6
# www.vlm.be/oc/rvv.htm;6
# Bedoeling;6
# zoek;1
# huisvesting;6
# netwerk;6
# efficiëntere;0
# toekomstmuziek;0
# bedoeling;6
# Voorlopig;0
# communicatiemiddel;6
# honderdtwintig;7
# SHM's;6
# socialekapitaalvennootschappen;6
# SKV's;6
# betere;0
# interactie;6
# informatie-uitwisseling;6
# Huisvestingsmaatschappijen;6
# overzicht;6
# rondzendbrieven;6
# woonnoodgebieden;6
# telefoonlijsten;6
# adressen;6
# notarissen;6
# briefwisseling;6
# zenden;11
# drastisch;0
# inperken;11
# verder;0
# stadium;6
# verbonden;11
# huisvestingsactoren;6
# lange;0
# termijn;6
# woonloket;11
# ambtenaar;6
# zit;11
# zoekt;11
# woord;6
# bovendien;1
# openbare;0
# instelling;6
# elektronisch;0
# handtekening;6
# e-mails;6
# authentieke;0
# waarde;6
# Besix;6
# droef;0
# voorbeeld;6
# ruzie;6
# kwadraat;6
# dezer;9
# afspeelt;11
# Betonmaatschappij;6
# BBM;6
# Belgiës;6
# grootste;0
# bouwbedrijven;6
# zelden;1
# vertoond;11
# Jean;6
# Stéphanne;6
# vice-president;6
# Smithkline;6
# Beecham;6
# bestuurder;6
# IBA;6
# IBt;6
# ruzies;6
# ontslag;6
# weekblad;6
# Trends;6
# beide;7
# alleen;0
# advocaten;6
# families;6
# debatcultuur;6
# hoog;0
# vaandel;6
# dragen;11
# ondertussen;1
# gebleken;11
# Ontgoocheld;11
# Dumolin;6
# vooruitzicht;6
# Ruzie;6
# heren;6
# stand;6
# overal;1
# weleens;1
# Paul;6
# baron;6
# Meester;6
# hoogleraar;6
# KU;6
# Leuven;6
# Verbond;6
# voor;6
# Belgische;6
# Ondernemingen;6
# prominente;0
# captain;6
# industry;5
# geest;6
# traditie;6
# begrepen;11
# Wat;9
# overblijft;11
# gênante;11
# spektakel;6
# bestuurders;6
# beursgenoteerd;11
# zaakjes;6
# elegant;0
# afhandelen;11
# familie;6
# regels;6
# schrijven;11
# onafhankelijke;0
# aanwijst;11
# tegengewicht;6
# bestuurders-aandeelhouders;6
# betwist;11
# transacties;6
# merkwaardige;0
# boeking;6
# vastgoedoperatie;6
# Polen;6
# vroeg;11
# raad;6
# opheldering;6
# JS;6
# corporate;6
# governance;6
# deugdelijk;0
# bestuur;6
# Belgisch;0
# probeert;11
# volgen;11
# papier;6
# gevolgd;11
# draait;11
# Tytgadt;6
# gelijk;0
# verwijten;11
# machtshonger;6
# rechtbank;6
# lijkt;11
# irrelevant;0
# geworden;11
# BBM;1
# beter;0
# commerciële;0
# naam;6
# sowieso;1
# macht;6
# elkaar;9
# verdelen;11
# ik;9
# gezien;11
# verwijderd;11
# tegelijk;1
# ontslagen;11
# bediende;6
# Verkopen;11
# prachtig;0
# Zo;1
# leden;6
# Stulemeijer;6
# oprichters;6
# ben;11
# verwonderd;11
# waarop;1
# geleid;11
# Christian;6
# TrustCapital;6
# een;7
# verbijsterd;11
# kijken;11
# Brusselse;0
# juni;6
# 20;7
# waard;0
# Men;9
# ontdekte;11
# negen;7
# meervleermuizen;6
# enkele;9
# vangen;11
# meervleermuis;6
# grotere;0
# vleermuizen;6
# noordelijke;0
# soort;6
# normaal;0
# voor;1
# populatie;6
# uiterst;0
# kwetsbaar;0
# zuidgrens;6
# voortplantingsgebied;6
# 50;7
# kilometer;6
# gedaald;11
# Zeeuws-;6
# West-Vlaanderen;6
# zogenaamde;0
# bat-detector;6
# bracht;11
# wetenschappelijk;0
# onderzoek;6
# stroomversnelling;6
# toen;3
# langs;8
# Ieperleekanaal;6
# Boezinge;6
# Kasteelgracht;6
# Ieper;6
# meervleermuizen;11
# waarnam;6
# vondst;6
# kraamkolonie;6
# feit;6
# uitwijzen;11
# diertjes;6
# overleven;11
# pleit;11
# inrichting;6
# ondergrondse;0
# ruimte;6
# vleermuizenreservaat;6
# toestel;6
# herkent;11
# typische;0
# vleermuisgeluiden;6
# nachtelijke;0
# duister;6
# opsporen;11
# Kort;0
# verblijfplaats;6
# ontdekt;11
# Speurders;6
# vzw;6
# Natuurreservaten;6
# Universiteit;6
# Ruca;6
# Wielewaal;6
# Boezinge;0
# kolonie;6
# gevonden;11
# evolutie;6
# verloopt;11
# voldoende;9
# voedsel;6
# zuiver;0
# water;6
# aangepaste;11
# biotoop;6
# Via;8
# radiotelemetrie;6
# mistnetten;6
# vangt;11
# zendertje;6
# opkleeft;11
# vluchtroutes;6
# kolonieplaats;6
# Eerste;7
# Hun;9
# uitverkoren;11
# ligt;11
# Noord-Nederland;6
# overwinteren;11
# meestal;1
# Noord-Frankrijk;6
# Begin;6
# netten;6
# opgehangen;11
# voetgangersbrug;6
# oude;0
# spoorwegbrug;6
# sluis;6
# Boezinge-dorp;6
# exemplaar;6
# kreeg;11
# mee;1
# speurders;6
# uiteindelijk;0
# spouwmuur;6
# gebouw;6
# leidde;11
# Nederlanders;6
# 1998;7
# gestart;11
# pensioenreserve;0
# Zolang;3
# overheidsobligaties;6
# overheidsschuld;6
# steil;0
# dalen;11
# extraatje;6
# belegd;11
# punt;6
# vaststelling;6
# Minder;7
# zeker;0
# modaliteiten;6
# antwoord;6
# geestelijke;0
# vader;6
# vice-premier;6
# Begroting;6
# trok;11
# delegatie;6
# kabinetsleden;6
# collega-ministers;6
# Den;6
# Haag;6
# Dankzij;8
# fonds;6
# uitgegeven;11
# waardoor;1
# later;0
# omhoog;1
# gereserveerde;0
# versnelde;11
# schuldafbouw;6
# voelt;11
# gesterkt;11
# ervaring;6
# hoeveel;7
# wanneer;1
# Anderen;9
# pompen;6
# EU-boekhoudnormen;6
# budgettair;0
# neutrale;0
# operatie;6
# bevolking;6
# bewust;0
# vergrijzingsproblematiek;6
# Liberalen;11
# impuls;6
# verdwijnt;11
# controle;6
# gingen;11
# AOW-spaarfonds;6
# ouderdomswet;6
# bestuderen;11
# belangrijker;0
# gefinancierd;11
# Hoeveel;7
# ?;10
# alsof;3
# je;9
# leent;11
# beleggen;11
# VLD-voorzitter;6
# Karel;6
# Gucht;6
# belegt;11
# Waarin;1
# Dat;3
# uitgangssituatie;6
# mate;6
# vergelijkbaar;0
# Daarom;1
# achten;11
# velen;7
# splitsen;11
# zaten;11
# zowel;3
# ziekteverzekering;6
# plan;6
# Zilverfonds;1
# hoge;0
# horden;6
# liberale;0
# hoek;6
# weerklinkt;11
# trouwens;1
# stelling;6
# stevig;0
# gespijsd;11
# wegvalt;11
# effectieve;0
# premier;6
# Guy;6
# Verhofstadt;6
# parlement;6
# State;6
# the;5
# Union;5
# aankondigen;11
# uitbouw;6
# pensioenspaarpot;6
# belangrijk;0
# educatief;6
# instrument;6
# Technisch;0
# spaarfonds;11
# virtuele;0
# staatssecretaris;6
# Sociale;6
# Zaken;6
# Hoogervorst;6
# VVD;6
# vindt;11
# nogal;1
# gek;0
# spaarfonds;1
# gelijkt;11
# sterk;0
# wettelijk;0
# pensioen;6
# 2010;7
# 2020;7
# kosten;6
# belegging;6
# afgetrokken;6
# staatsschuld;6
# Gaat;11
# Hoewel;3
# standpunt;6
# gesteund;11
# moeilijk;6
# Velen;7
# kapitaal;6
# UMTS-veiling;6
# kans;6
# sanering;6
# gereserveerd;11
# vertonen;11
# ander;9
# verloop;6
# pensioenuitgaven;6
# Enerzijds;1
# eindelijk;1
# evenwicht;6
# gebracht;11
# Belgrado;6
# Sainovic;6
# Milosevic;6
# Kosovo;6
# Montenegro;6
# Navo-troepen;6
# provincie;6
# Joegoslavië-Tribunaal;6
# wegens;8
# misdaden;6
# menselijkheid;6
# aangeklaagd;11
# arresteren;11
# Buitenland;11
# president;6
# bemachtigen;11
# Overigens;1
# VN-bestuur;6
# Unmic;6
# besloten;11
# Serviërs;6
# mogen;11
# stemmen;11
# grondwetswijziging;6
# doorgevoerd;11
# Joegoslavische;0
# Slobodan;6
# bezoek;6
# brengen;11
# topminister;6
# Nikola;6
# persconferentie;6
# zonder;3
# evenwel;1
# datum;6
# vermelden;11
# AFP;6
# inwoners;6
# Joegoslavië;6
# nieuw;0
# bezocht;11
# 1997;7
# verkiezing;6
# federale;0
# verklaring;6
# daags;1
# onverwacht;0
# Gorica;6
# Gajevic;6
# secretaris-generaal;6
# 1999;7
# bestuurd;11
# Verenigde;6
# Naties;6
# Indien;3
# begeeft;11
# basis;6
# aanklacht;6
# Navo;6
# opgepakt;11
# reageerde;11
# woordvoerder;6
# alliantie;6
# nieuws;6
# Verboden;11
# verkiezingsstunt;6
# leerlingenraden;6
# marginaal;6
# gebeuren;11
# kinderrechtencommissaris;6
# Ankie;6
# Vandekerckhove;6
# scholierenkoepel;6
# uniformplicht;6
# sommige;9
# VSK;9
# meent;11
# piercings;0
# leerlingenstatuut;6
# schoolreglement;6
# gevoegd;11
# en;1
# statuut;6
# vormt;11
# aanvulling;6
# decreet;6
# bepaalt;11
# secundaire;0
# school;6
# één;6
# derde;7
# erom;1
# Zo'n;9
# conflicten;6
# vermijden;11
# plichten;6
# leggen;11
# initiatief;6
# Kinderrechtencommissariaat;6
# VSK;6
# toegestaan;11
# weigeren;11
# huiswerk;6
# zwaar;0
# enzovoort;1
# magda'-campagne;0
# informeren;11
# voorziet;11
# bemiddelings-;6
# geschillencommissie;6
# Scholierenkoepel;6
# stoomde;11
# klaar;0
# gelijkheid;6
# evaluatie-;0
# tuchtprocedures;6
# inzagerecht;6
# inspraak;6
# bevat;11
# godsdienstvrijheid;6
# hoofddoek;6
# moslimmeisjes;6
# vrijheid;6
# uiterlijk;6
# vragen;6
# terecht;1
# 02;6
# 215.32.29;7
# schooldag;6
# uur;6
# privacy;6
# dringt;11
# invoering;6
# middelbaar;6
# data;6
# mobiele;0
# telefoon;6
# Door;3
# veilingen;6
# drijven;11
# namelijk;1
# prijs;6
# iemand;9
# betaald;11
# 100;7
# dollar-vraag;6
# jonge;0
# slimme;0
# ingenieur;6
# opstaan;11
# technologie;6
# ontwikkelt;11
# UMTS-capaciteit;6
# gsm;6
# Opvallend;11
# Belgacom-baas;6
# kritiek;6
# houding;6
# se;1
# veiling;6
# licenties;6
# consumentenorganisaties;6
# vreest;11
# toekomstige;0
# particuliere;0
# klanten;6
# opdraaien;11
# investeringen;6
# geeft;11
# schuld;6
# van;1
# Goossens;1
# keuze;6
# gelovers;6
# UMTS-toepassingen;6
# diegenen;9
# geloven;11
# Zal;11
# lancering;6
# UMTS;6
# vertragen;11
# licentie;6
# operatoren;6
# voorsprong;6
# gaf;11
# vergelijk-bare;0
# goedkopere;0
# Daartegenover;1
# inkomsten;6
# mij;9
# verbaast;11
# UMTS-zaak;6
# controleert;11
# weinig;7
# waarschijnlijk;0
# Belgacom;6
# Mobile;6
# meedoen;11
# Er;1
# dimensie;6
# verhaal;6
# sluit;11
# onthouding;6
# UMTS-licentie;6
# Zullen;11
# fabrikanten;6
# componenten;6
# betreft;11
# aard;6
# onzekerheden;6
# Nog;1
# vraag;11
# toeleveranciers;6
# Nu;1
# Officieel;0
# meedoet;11
# welk;9
# hoorde;11
# 750;7
# dollar;6
# 33,7;7
# miljard;7
# interesten;6
# zotte;0
# collega-operatoren;6
# Groot-Brittannië;6
# betaalden;11
# vat;6
# vol;0
# aanzienlijk;0
# prijskaartje;6
# operator;6
# reeds;1
# uitgebreid;11
# dus;1
# opbouwkosten;6
# uitschakelen;11
# gsm-netwerken;6
# volgden;11
# pauzes;6
# Sommige;9
# ratingbureaus;6
# ratio's;6
# verlaagden;11
# lenen;11
# daarover;1
# serieuze;0
# leest;11
# ene;9
# verkeer;6
# 60;7
# Josse;6
# Abrahams;6
# Waar;1
# sta;11
# miljarden;7
# Wij;9
# bereiden;11
# mentaal;0
# John;6
# vraag;6
# voorbereid;11
# kostprijs;6
# mobilofonie;6
# wijst;11
# schuldigen;0
# bedenkingen;6
# wij;9
# vergunning;6
# vijftien;7
# rekening;6
# Overal;1
# klagende;11
# telecomtoplui;6
# horen;11
# overheden;6
# viseerden;11
# overigens;1
# discriminatie;6
# Waarschijnlijk;0
# valt;11
# maand;6
# behoefte;6
# schoonmoeder;6
# life;5
# scherm;6
# mobilofoon;6
# Hoe;1
# breder;0
# doelpubliek;6
# erg;0
# verbazen;11
# mobilfoonoperator;6
# Vodafone;6
# participeert;11
# afzijdig;0
# businessplan;6
# vijfmaal;1
# maximum;6
# betaalde;11
# opgenomen;11
# opnamen;6
# binnen-;6
# buitenland;6
# half;0
# december;6
# duren;11
# economisch;0
# resultaat;6
# altijd;1
# dikke;0
# vinger;6
# pap;6
# budget;6
# bedraagt;11
# gulden;6
# 445;7
# bijzonder;0
# productie;6
# beroep;6
# gedaan;11
# filmmaatschappijen;6
# 3;7
# voorbereidingsperiode;6
# acteur-regisseur;6
# Jeroen;6
# Krabbé;6
# kasteel;6
# Het;6
# Nijenhuis;6
# Heino;6
# begonnen;11
# verfilming;6
# Discovery;6
# Heaven;5
# roman;6
# Ontdekking;6
# Hemel;6
# Harry;6
# Mulisch;6
# onze;9
# noorderburen;6
# speelfilms;6
# gedraaid;11
# beknopt;11
# kern;6
# verschijnen;11
# 1992;7
# begroet;11
# totaalwerk;6
# filosofie;6
# natuurkunde;6
# getallenleer;6
# linguïstiek;6
# architectuur;6
# bijzonder;6
# kosmologie;6
# ingenieus;0
# én;6
# persoonlijke;0
# geschiedenis;6
# engel;6
# zorgt;11
# ervoor;1
# aarde;6
# geboren;0
# opdracht;6
# negenhonderd;7
# 65;7
# hoofdstukken;6
# personages;6
# motieven;6
# gebeurtenissen;6
# thema's;6
# beïnvloed;11
# gunstige;0
# regeling;6
# opvallend;11
# Nederlands;0
# privé-geld;6
# beschikbaar;0
# filmfinanciering;6
# testimonium;6
# geboden;11
# teruggebracht;11
# hemel;6
# debuteerde;11
# '97;7
# Left;6
# Luggage;6
# Koffers;6
# Vol;0
# schrijfster;6
# Carl;6
# Friedman;6
# filmt;11
# Mulisch-hemel;6
# filmmakers;6
# wetenschap;6
# wetten;6
# Mozes;6
# verdrongen;11
# gesmeed;11
# verbond;6
# God;6
# mens;6
# ongedaan;0
# verfilmde;11
# boeken;6
# Aanslag;6
# Fons;6
# Rademakers;6
# 86;7
# theaterroman;6
# Hoogste;6
# Tijd;6
# Frans;6
# Weisz;6
# 94;7
# George;6
# Sluizer;6
# 78;7
# zomer;6
# bioscopen;6
# Wél;6
# verzoek;6
# Engelse;0
# acteur;6
# Stephen;6
# Fry;6
# Oscar;6
# Wilde-film;6
# cast;6
# toegevoegd;11
# Auteur;6
# nauw;0
# betrokken;11
# bemoeien;11
# Toen;3
# boek;6
# schreef;11
# wilde;11
# persbureau;6
# ANP;6
# GIB;6
# pakket;6
# 57;7
# verkoopt;11
# aandeelhouderswaarden;11
# boven;1
# gehaald;11
# steeg;11
# zelfs;1
# 23,15;7
# koers;6
# Real;6
# Software;6
# 1,23;7
# weging;6
# 8,64;7
# stijgen;11
# EVS;6
# maker;6
# apparatuur;6
# tv-beelden;6
# 2,67;7
# mooie;0
# halfjaarcijfers;6
# vielen;11
# winstwaarschuwing;6
# onverwachts;1
# verplaatst;11
# GIB-dochter;6
# Quick;6
# 2,77;7
# VVPR-versie;6
# 3,53;7
# Aangenomen;11
# BNP;6
# Paribas;6
# distributiegroep;6
# druk;6
# gezet;11
# aandeelhouderswaarde;11
# duur;0
# koersstijging;6
# creëren;11
# Bel;11
# 20-index;7
# 2,28;7
# 0,07;7
# 3.132,52;7
# Ion;6
# Beam;6
# Applications;6
# daling;6
# 3,39;7
# Bloomberg;6
# Computerdistributeur;6
# Systemat;6
# lag;11
# vredig;0
# bij;1
# Netwerkspecialist;6
# Telindus;6
# 2,50;7
# 143,5;7
# forse;0
# even;1
# anders;1
# herschikking;6
# consequenties;6
# bevestigd;11
# opvolger;6
# Cobepa;6
# free;6
# float;11
# beneden;8
# GIB-verhaal;6
# bleef;11
# doorgaan;11
# GIB-waarde;11
# Fidelity;6
# handje;6
# toesteken;11
# interpretatie;6
# verschilde;11
# analist;6
# gehouden;11
# Defeyt;6
# vatte;11
# alternatief;6
# punten;6
# lokale;0
# alternatieve;0
# energiebronnen;6
# stimulans;6
# ontwikkelingssamenwerking;6
# vlak;1
# BE;0
# beeld;6
# trekt;11
# Ecolo;6
# stembus;6
# zusterpartij;6
# start;6
# verkiezingscampagne;6
# winning;6
# mood;5
# boodschap;6
# Franstalig;6
# gemeentepolitiek;6
# groen;0
# stemmen;6
# groenen;6
# recordaantal;6
# 207;7
# 149;7
# prat;11
# pariteit;6
# man;6
# vrouw;6
# nagenoeg;1
# plaatsen;6
# lijst;6
# gemeenten;6
# kant;6
# heersende;11
# rond-rond;6
# steekt;11
# legde;11
# politiek;0
# secretaris;6
# Philippe;6
# Bart;6
# Eeckhout;6
# Vandaar;1
# aanzet;6
# platgetreden;6
# paden;6
# verlaten;11
# blauw;0
# verkeersbord;6
# verkeersplein;6
# pijl;6
# radicaal;0
# aanbod;6
# gold;11
# doorverkopen;11
# jongstleden;11
# Versatel;6
# openstelling;6
# beschuldigt;11
# kwade;0
# bedoelingen;6
# binnen;8
# uitspraak;6
# Nathalie;6
# Brys;6
# directeur;6
# regelgeving;6
# aankondiging;6
# doorhad;6
# klacht;6
# ingediend;11
# Hetzelfde;9
# gezegd;11
# concurrenten;6
# ADSL;6
# koperdraad;6
# opwaardeert;11
# capaciteiten;6
# glasvezel;6
# negatief;0
# toonde;11
# allesbehalve;1
# tevreden;0
# beticht;11
# hinderen;11
# concurrent;6
# geliberaliseerde;11
# neiging;6
# moeilijkheid;6
# veroveren;11
# marktaandeel;6
# wangedrag;6
# obstructiepolitiek;6
# gegevens;6
# relatief;0
# telefoonmaatschappij;6
# aanpassen;11
# Vorige;0
# vierde;7
# kwartaal;6
# Daarna;1
# beweging;6
# deur;6
# aansluitingspunten;11
# voormalige;0
# monopolisten;6
# stukje;6
# openstellen;11
# gebruikers;6
# richt;11
# kmo's;6
# nabijheid;6
# glasvezelnetwerk;6
# bijkomende;11
# toestemming;6
# gebruiken;11
# eindje;6
# Belgacom-netwerk;6
# huis;6
# kantoor;6
# klant;6
# tevredener;0
# klantentevredenheid;6
# Nederland;6
# beursgenoteerde;11
# telefoonbedrijf;0
# mededingingsautoriteiten;6
# geleden;1
# local;6
# loop;11
# aansluitnet;6
# tariefvoorstel;6
# studenten;6
# apotheek;6
# combineren;11
# gezin;6
# parttime;6
# soms;1
# hoogte;6
# recente;0
# ontwikkelingen;6
# geneesmiddelen;6
# artsen;6
# vertegenwoordiger;6
# vertelt;11
# vervangingspool;6
# vliegende;11
# apothekers;6
# reserve;6
# geraakt;11
# vlug;0
# Terwijl;3
# dringend;1
# morgen;6
# Drie;7
# vacatures;6
# openstaan;11
# Katrijn;6
# Serneels;6
# Vaak;1
# persoon;6
# vervangen;11
# apotheker;6
# pillendraaier;6
# bollenwinkel;6
# achterhaald;11
# Antwerpse;0
# 71;7
# 16;7
# professor;6
# Haemers;6
# pro-departementsvoorzitter;6
# farmacie;6
# RUCA-universiteit;6
# van;6
# biomedische;0
# wetenschappen;6
# inhoudelijk;0
# dicht;1
# lijken;11
# milieubewust;0
# klinkt;11
# zalfjes;6
# pillen;6
# laboratorium;6
# verkopen;11
# merkgeneesmiddelen;11
# Want;3
# kleinere;0
# spring;11
# dokter;6
# binnen;1
# vroeger;0
# groter;0
# saaie;0
# imago;6
# apothekersmetier;6
# klopt;11
# bedrijfsleven;6
# winkelier;6
# witte;0
# jas;6
# halve;0
# wetenschapper;6
# totaal;0
# kiest;11
# daalt;11
# scheikunde;6
# dramatisch;0
# richtingen;6
# bio;6
# milieu;6
# bio-ingenieur;6
# milieucontroleur;6
# noem;11
# job;6
# vóór;6
# Dreigend;11
# tekort;6
# door;1
# Kwamen;11
# 1990;7
# 400;7
# 250;7
# 40;7
# Tien;7
# reden;6
# verplegers;6
# onderwijzers;6
# kent;11
# telefoontjes;6
# Dimitri;6
# Sascha;6
# assistenten;6
# Zweden;6
# Portugal;6
# laag;0
# tekort;1
# onderwijshervorming;6
# bus;6
# duurt;11
# twintig;7
# professoren;6
# wanhopig;0
# naar;1
# verbetering;6
# alternatieven;6
# hopen;11
# trend;6
# keren;11
# bedrijfslaboratorium;6
# apothekersbalie;6
# balie;6
# industrie;6
# ziekenhuis;6
# aparte;0
# specialisaties;6
# extra;0
# specialisatiejaar;6
# achteraf;1
# Daarmee;1
# sluiten;11
# nood;6
# hervormen;11
# ver;0
# merkbaar;0
# Scheikunde;6
# blijkbaar;1
# stinkende;11
# gevaarlijke;0
# dampen;11
# voornaamste;0
# job;5
# is;5
# eigenlijk;0
# brug;6
# dokters;6
# kopieercentra;6
# zijn;6
# vragen;11
# genoteerd;11
# hoeveelheden;6
# toegangsbewijzen;11
# DS;6
# danstent;6
# spelen;11
# Far;6
# West;6
# Crew;6
# Bobohill;6
# Soundsystem;6
# Fiji;6
# Sound;6
# Zion;6
# Train;6
# organisatoren;6
# Hove;6
# live;1
# wijzen;11
# festival;6
# vervalste;11
# toegangskaarten;6
# omloop;6
# Vervalste;0
# kaarten;6
# Steenhaut;6
# plaatsvindt;11
# gemeentepark;6
# 12.45;7
# dergelijke;9
# fraude;6
# klein;0
# doodssteek;6
# betekenen;11
# levensbelang;6
# bezoekers;6
# voorverkooppunten;6
# aanschaffen;11
# podium;6
# Humb;6
# Starflam;6
# Mad;6
# Professor;6
# Think;6
# One;6
# Marrakech;6
# Emballages;6
# Ensemble;6
# Orishas;6
# Manu;6
# Dibango;6
# Dirty;6
# Beatniks;6
# beleid;6
# gericht;11
# handhaven;11
# stabiele;0
# kwakkelende;11
# munt;6
# bezorgt;11
# kopzorgen;11
# slecht;0
# economie;6
# verwachting;6
# groeien;11
# 4,9;7
# 3,4;7
# eurozone;6
# rentestijging;6
# dijken;11
# groeiritme;6
# gleed;11
# 0,8950;7
# 0,8844;7
# werkloosheid;6
# elf;7
# 9,7;7
# groeit;11
# Ierland;6
# wellicht;1
# vermoedelijke;0
# inflatiegevaar;6
# eventuele;0
# rentestijgingen;6
# kop;6
# indrukken;11
# hand;6
# zwakke;0
# gestegen;11
# olieprijzen;6
# daarmee;1
# dieptepunt;6
# Critici;6
# noemen;11
# contraproductief;6
# tracht;11
# Rente;0
# hoger;0
# Vorig;0
# november;6
# stond;11
# tarief;6
# ingedrukt;11
# strategie;6
# Consumentenprijzen;6
# stegen;11
# 2,4;7
# bank;6
# aanhoudt;11
# prijsstabiliteit;6
# heropleving;6
# fnuiken;11
# Analisten;6
# betwijfelen;11
# bekommert;11
# gevaar;6
# afkoeling;6
# weggewuifd;11
# versterken;11
# eenheidsmunt;6
# aangetast;11
# Euro;6
# verteert;11
# tast;11
# herfinancieringsrente;6
# belangrijkste;0
# 0,25;7
# procentpunt;11
# opgetrokken;11
# liggend;11
# recept;6
# verwonderlijk;0
# Frankfurt;6
# jongste;0
# verteren;11
# duwtje;6
# onveranderd;0
# fase;6
# stevige;0
# lezen;11
# perscommuniqué;6
# industriële;0
# omlaag;1
# groeiverhaal;0
# lippendienst;6
# Geert;6
# Noels;6
# hoofdeconoom;6
# beurshuis;6
# Petercam;6
# Binnen;8
# tellende;11
# verschillen;11
# groeicijfers;6
# Sinds;8
# 11,5;7
# noteerde;11
# 0,8846;7
# kruistocht;6
# contraproductief;0
# Gustav-Adolf;6
# Horn;6
# hoofdeconomist;11
# toonaangevende;0
# DIW;6
# Instituut;6
# daalde;11
# zesde;7
# maal;6
# verhoogd;11
# soelaas;6
# Catherine;6
# Vuylsteke;6
# Birmese;0
# idylle;6
# tenminste;1
# voorstelling;6
# militaire;0
# junta;6
# Of;3
# westers;0
# diplomaat;6
# hetzelfde;9
# Schermend;11
# veiligheid;6
# 55-jarige;0
# Aung;6
# San;6
# lieten;11
# lucht;6
# banden;6
# reisgezellen;6
# ambulance;6
# paar;6
# tientallen;6
# meters;6
# Toegegeven;11
# Sans;6
# avonturen;6
# Dalla;6
# onopgemerkt;0
# gebleven;11
# Nationale;0
# Democratie;6
# Liga;6
# zuiden;6
# bezoeken;11
# gekomen;11
# werkelijkheid;6
# Nobelprijswinnares;6
# Suu;6
# Kyi;6
# onderhand;1
# confrontatie;6
# regerende;11
# militairen;6
# universiteiten;6
# aangezien;3
# onrust;6
# daartoe;1
# noopt;11
# Bijgevolg;1
# zag;11
# doet;11
# Thaise;0
# reactie;6
# tal;6
# opposanten;6
# hart;6
# riem;6
# moeilijkheden;6
# zoeken;11
# verwijten;6
# staatshoofden;6
# regeringsleiders;6
# Nauwelijks;1
# Daw;6
# reisgenoten;6
# rusten;11
# charmant;0
# stadje;6
# minuten;6
# boot;6
# hoofdstad;6
# Acht;7
# 98;7
# indicatie;6
# levert;11
# Is;11
# sindsdien;1
# vooruitgang;6
# geboekt;11
# Zelfs;1
# Buitenlandse;6
# Bangkok;6
# crisis;6
# Birma;6
# mantel;6
# der;2
# liefde;6
# bedekt;11
# Toen;1
# dertien;7
# uitdrogingsverschijnselen;6
# afgevoerd;11
# huisarrest;6
# geplaatst;11
# opgeheven;11
# bewegingsvrijheid;6
# gehad;11
# Thailand;6
# bezorgd;11
# geplande;11
# Asean-landen;6
# Laos;6
# bezoekt;11
# Sarpachaun-buurt;6
# reisgenoten;11
# stadscentrum;6
# dagelijks;0
# duik;11
# Sarpachaun-stroom;6
# heette;11
# zomaar;1
# binnenlandse;0
# aangelegenheid;6
# zaak;6
# roet;6
# eten;6
# gooit;11
# Brit;6
# Michael;6
# Aris;6
# '98;7
# terminaal;6
# kankerpatiënt;1
# mocht;11
# vestigen;11
# trieste;0
# '90;7
# verpletterende;11
# verkiezingszege;0
# behaalde;11
# CV;6
# Kamperende;11
# kompanen;6
# meebrengen;11
# eenmaal;1
# spaceshuttle;0
# aangekomen;11
# Ikon-satelliet;6
# natuurlijk;0
# Russen;6
# collega's;6
# álles;6
# verteld;11
# viertal;6
# testpiloten;6
# luchtmacht;6
# bereidt;11
# afzienbare;0
# verkennen;11
# beslist;1
# opgerichte;11
# burgerbedrijf;0
# Nasa;6
# roer;6
# overnemen;11
# Festival;6
# Venetië;6
# Space;6
# Cowboys;6
# première;6
# zeventigjarige;0
# Clint;6
# Eastwood;6
# actrice;6
# Sharon;6
# Stone;6
# Gouden;6
# Leeuw;6
# carrière;6
# overhandigd;11
# gelauwerde;11
# besloot;11
# dankwoord;6
# woorden;6
# Grazie;6
# mi;6
# Sergio;6
# for;5
# this;5
# Leone;5
# gelegenheid;6
# uiteraard;1
# herinnerd;11
# indertijd;1
# gelanceerd;11
# spaghettiwesterns;6
# Leone;6
# Hollywood;6
# beroerd;0
# geweest;11
# allerlei;9
# snelle;0
# verfilmingen;6
# actualiteit;6
# verzilveren;11
# gave;6
# profetie;6
# weliswaar;1
# pure;0
# Hollywood-fictie;6
# onmogelijk;0
# fatale;0
# catastrofe;6
# Russische;0
# kernonderzeeër;6
# Koersk;6
# Houston;6
# klaren;11
# ingenieurs;6
# snappen;11
# ouderwetse;0
# opent;11
# Eastwoods;6
# Rusland;6
# totale;0
# communicatieblack-out;6
# veroorzaken;11
# burgeroorlog;6
# !;10
# Argwaan;6
# verband;6
# toestand;6
# spitstechnologie;6
# misplaatst;11
# Dan;1
# springt;11
# decennia;6
# piloten;6
# Team;5
# Daedalus;5
# vormden;11
# ruimtedromen;6
# opbergen;11
# China;6
# Syndrome;5
# nucleair;0
# incident;6
# centrale;6
# effectief;0
# misliep;11
# kerncentrale;0
# Three;6
# Mile;6
# Island;6
# Harrisburg;6
# Ostankino-toren;6
# fik;6
# enige;9
# argwaan;6
# Koude;0
# Oorlog;6
# inmiddels;1
# behoorlijk;0
# gegeneerd;11
# wanneer;3
# fel;0
# verouderde;11
# communicatiesatelliet;11
# Ikon;6
# geraken;11
# neer;1
# storten;11
# depanneert;11
# satelliet;6
# Technologische;0
# spionage;6
# woensdagavond;6
# 57ste;7
# officieel;0
# geopend;11
# Amerikanen;6
# allerijl;6
# beletten;11
# communicatiesatelliet;6
# pletter;6
# slaat;11
# ontwerper;6
# weleer;1
# Frank;6
# Corvin;6
# leider;6
# Daedalus-project;6
# wél;0
# ontdekken;11
# identiek;0
# geleidingssysteem;0
# beschikt;11
# Skylab-satelliet;6
# proloog;6
# anno;8
# 1958;7
# knarren;6
# Tommy;6
# Lee;6
# Jones;6
# Donald;6
# Sutherland;6
# James;6
# Garner;6
# kortste;0
# keren;6
# astronaut;6
# opgeleid;11
# vooralsnog;1
# ruimtedroom;6
# verwezenlijken;11
# Luc;6
# Vandewalle;6
# merken;11
# mogelijkheden;6
# verzekeringsproducten;6
# bankkanalen;6
# implementeren;11
# toelichting;6
# BBL;6
# ING;6
# verantwoordelijk;0
# bankverzekeringsactiviteiten;6
# Zwitserland;6
# verdubbelen;11
# Vandewalle;0
# uitvoering;6
# brainstorm;6
# BBL-topmanagers;6
# Mensen;6
# Al;3
# winstgroei;6
# dankzij;8
# commissies;6
# meevaller;6
# 10,7;7
# 8,8;7
# Werk;6
# sessie;6
# genereerde;11
# 350;7
# voorstellen;6
# besparingen;6
# 26;7
# strategische;0
# uitwerken;11
# verdwijnen;11
# afslankingsoperatie;6
# 120;7
# merken;6
# gemeenschappelijke;0
# platformen;6
# ING-groep;6
# Voorzitter;6
# voorbije;0
# halfjaar;6
# nettowinst;6
# 303,9;7
# 31,6;7
# dezelfde;9
# periode;6
# Nederlanden;6
# Postbank;6
# sterkste;0
# --;5
# 7,5;7
# Vlaming;6
# doorschuiven;11
# Michel;6
# Tilmant;6
# voortaan;1
# moedermaatschappij;6
# gekregen;11
# expansie;6
# daarvan;1
# aanwezigheid;6
# verzekeraar;6
# uitbouwen;11
# Green;6
# m;6
# El-Guerrouj;6
# 1500;7
# Solberg-Hattestad;6
# speerwerpen;6
# Kotova;6
# verspringen;6
# Berlijn;6
# goud;6
# Bert;6
# Leenaerts;6
# Memorial;6
# Damme;6
# schitterende;11
# mijl;6
# Amerikaan;6
# Maurice;6
# Greene;6
# Marokkaan;6
# Hicham;6
# Noorse;0
# Trine;6
# Tatiana;6
# Golden;6
# League-meeting;6
# vijftig;7
# kilogram;6
# goud;0
# eisen;11
# atletiekfederatie;6
# IAAF;6
# verdeeld;11
# kader;6
# League;6
# atleten;6
# zeven;7
# meetings;6
# Belgen;6
# Gail;6
# Devers;6
# zege;6
# Parijs;6
# Rome;6
# Oslo;6
# Monte;6
# Carlo;6
# goud-zoekers;6
# Mohamed;11
# Mourhit;6
# recordhouder;6
# traint;6
# competitieritme;0
# Persagentschappen;6
# Golden;5
# League-circuit;5
# meeste;7
# thuisfront;6
# alvorens;3
# reizen;11
# Sydney;6
# Zeneemt;11
# rust;6
# discuswerper;0
# Jo;6
# Daele;6
# olympische;0
# Atletiek;6
# blikvangers;6
# Duitse;0
# Marion;6
# Johnson;6
# PG;6
# Peter;6
# Goris;6
# Waardoor;1
# Milieu-inspectie;6
# sterke;0
# twijfels;6
# milieuwetgeving;6
# wetende;11
# diezelfde;9
# toezichtbevoegdheid;6
# voordien;1
# 1.100;7
# processen-verbaal;6
# 12.000;7
# inspecties;6
# dioxine-uitstoot;6
# rapport;6
# tienmaal;1
# verminderd;11
# 126;7
# gevallen;6
# verschillende;11
# parketten;6
# minnelijke;0
# schikking;6
# rand;6
# containerparken;6
# beschikten;11
# noodzakelijke;0
# milieuvergunning;6
# ministerie;6
# Gemeenschap;6
# 11.595;7
# uitgevoerd;11
# voorgestelde;11
# Milieuhandhavingsrapport;6
# Boven;1
# normale;0
# controles;6
# prioritair;0
# milieubelastende;11
# klasse;6
# inspectie;6
# dioxine-;6
# Coca;6
# Cola-crisis;6
# boterham;6
# 27;7
# milieu-inbreuk;6
# rechter;6
# overtreders;6
# stuk;6
# veroordeeld;11
# Cola-incident;6
# moesten;11
# tachtig;7
# liter;6
# frisdrank;0
# legale;0
# dioxinecrisis;6
# toezien;11
# verwerking;6
# tienduizenden;7
# tonnen;6
# afval;6
# vernietigde;11
# vee-;6
# voedingsstocks;0
# Goed;0
# ongekroonde;11
# dioxinekoning;6
# Sidmar;6
# name;6
# omstreden;0
# Isvag-installatie;6
# herhaaldelijk;0
# stilgelegd;11
# oven;6
# streng;0
# zelfcontrole-;6
# meetprogramma;6
# opgelegd;11
# 293;7
# geïnspecteerde;0
# gemeentelijke;0
# PCB-verontreiniging;6
# MI;6
# omschrijft;11
# hectisch;0
# huisvuilverbrandingsinstallaties;6
# werking;6
# permanent;0
# wettelijke;0
# emissiewaarden;6
# voldoen;11
# besluit;11
# Daarnaast;1
# nasleep;6
# 646;7
# opslagplaatsen;6
# vetten;6
# oliën;6
# gecontroleerd;11
# na;1
# welke;9
# PCB;6
# dioxineverontreiniging;6
# verspreid;11
# 785;7
# intensieve;0
# verbrandingsovens;6
# installaties;6
# voorgaande;0
# boven;8
# opgelegde;11
# uitstootnormen;6
# dioxine;6
# werkte;11
# Daarbij;1
# inbreuken;6
# Verbrandingsovens;1
# norm;6
# Caïro;6
# Palestijnse;0
# Arafat;6
# Arabische;0
# Oost-Jeruzalem;6
# Palestina;6
# Nieuwe;0
# Palestijns-Israëlische;0
# topontmoeting;6
# gedeeld;11
# Israël;6
# stichten;11
# zonder;8
# reisbeperkingen;6
# stadsdelen;6
# heilige;0
# toegankelijk;0
# Joodse;0
# Jeruzalem;6
# Ehud;6
# Olmert;6
# uitgesproken;11
# optie;6
# goddelijke;0
# soevereiniteit;6
# Israëlische;0
# Justitie;6
# Yossi;6
# Beilin;6
# formuleerde;11
# Egypte;6
# Palestijnen;6
# delen;6
# eenheid;6
# tasten;11
# dossier;6
# definitieve;0
# status;6
# knelpunt;6
# vredesdialoog;6
# merkwaardig;0
# hiermee;1
# steunt;11
# tactiek;6
# Likoed;6
# juist;0
# bestaat;11
# regeringsuitspraak;6
# kraken;11
# ernaar;1
# Yasser;6
# Barak;6
# staat;6
# joden;6
# moslims;6
# christenen;6
# makkelijker;0
# Egyptenaren;6
# blitzbezoek;6
# Clinton;6
# voortzetting;6
# quo;6
# inhoudt;11
# veiligheidscontrole;0
# Tempelberg;6
# terzelfdertijd;1
# toegang;6
# lid;6
# rechtse;0
# Likoed-partij;6
# circuleren;6
# verhalen;11
# 13;7
# uitgeroepen;11
# actiefste;0
# bemiddelaar;6
# conflict;6
# paus;6
# religieuze;0
# trekpleisters;6
# beheer;6
# plaatsen;11
# FS;6
# 1988;7
# Bevrijdingsbeweging;6
# PLO;6
# Algiers;6
# formeel;0
# soevereine;6
# uitriep;11
# Schlömer;6
# Daardoor;1
# vredesonderhandelaars;6
# novemberdag;1
# symbolische;0
# betekenis;6
# stadsdeel;6
# Zesdaagse;0
# geannexeerd;11
# eist;11
# honderd;7
# vaststaat;11
# toponderhandelaar;6
# Nabil;6
# Saath;6
# bijeenkomst;6
# bestempeld;11
# wonen;11
# millenniumtop;6
# verwerpen;11
# overlaten;11
# Statuut;0
# open;0
# verklaarde;11
# Egyptische;0
# Amr;6
# Moussa;6
# onverbiddelijk;0
# vlag;6
# wapperen;11
# Bill;6
# optreden;11
# überhaupt;11
# Soeharto-proces;6
# proces;6
# plaatsvinden;11
# landbouwministerie;6
# Jakarta;6
# Habibie;6
# slaagde;11
# aftreden;11
# stop;0
# verdediging;6
# beroertes;6
# gisterochtend;1
# onderzocht;11
# ongeschikt;0
# bevond;11
# bijwonen;11
# 79-jarige;0
# Soeharto;6
# ziek;0
# beklaagdenbankje;6
# theorie;6
# corruptie;6
# levenslang;0
# Wahid;6
# voorhand;6
# beloofd;11
# amnestie;11
# gedurende;8
# 32;7
# uitleggen;11
# 545;7
# verdwenen;11
# overheidsfondsen;6
# gebeurd;11
# lot;6
# wacht;11
# bejaarde;0
# recupereren;11
# honderden;7
# gietende;11
# regen;6
# aanklager;6
# onafhankelijk;0
# team;6
# onderzoekt;11
# Waarnemers;6
# test;6
# Indonesiës;6
# fragiele;6
# democratie;6
# komaf;6
# erfenis;6
# Orde;6
# Soeharto's;6
# regime;6
# genoemd;11
# stuurt;11
# kat;6
# ontgoocheling;6
# wegblijven;11
# enorm;0
# uitgesteld;11
# Miljoenen;6
# Indonesiërs;6
# buis;6
# wachtend;11
# verlossende;11
# livebeelden;6
# Hang;6
# scandeerden;11
# nam;11
# heikele;0
# onderdeel;6
# belofte;6
# daadwerkelijke;0
# democratisering;6
# zorgen;11
# Bus;6
# gratis;0
# bejaarden;0
# meldt;11
# krant;6
# Maariv;6
# bedacht;11
# politieman;6
# openbaar;0
# vervoer;6
# aangeboden;11
# Nederlandstalige;0
# senioren;6
# Jonge;0
# boefjes;6
# verplicht;11
# theater;6
# voorlopige;0
# Dienst;6
# Preventie;6
# Luchtvaartongevallen;6
# BEA;6
# bevestigt;11
# metalen;0
# strip;6
# landingsbaan;6
# band;6
# Concorde;6
# opengereten;11
# waarna;1
# vliegtuig;6
# kettingreactie;6
# nabij;0
# neerstortte;11
# ongeval;6
# toont;11
# vernietiging;6
# voordoen;11
# catastrofale;0
# stadsbestuur;6
# rechte;0
# pad;6
# recidivisten;6
# beperken;11
# metaalstrip;6
# gaten;6
# luchtvaart;6
# gebruikte;11
# spijkers;6
# pasten;11
# betaalt;11
# proefproject;6
# maatregelen;6
# hieromtrent;1
# Brussels;0
# Verkeer;6
# Jos;6
# Chabert;6
# gehele;0
# voordelen;6
# toekent;11
# straffen;6
# Concorde-rapport;6
# strip'-theorie;6
# gisteravond;1
# internet;6
# gezette;11
# conclusies;6
# Zuid-Israëlische;0
# Beersheba;6
# jeugdige;0
# misdadigers;6
# oud;0
# dwingen;11
# concerten;6
# surfen;11
# rondreizen;6
# ondernemen;11
# pleit;6
# toegekend;11
# blokkades;6
# duizenden;7
# toeristen;6
# terugkeerden;11
# vakantie;6
# ellende;6
# wachttijden;6
# bedroegen;11
# personenverkeer;6
# levering;6
# haven;6
# gedrang;6
# Galvany;6
# daarentegen;1
# beloofde;11
# zowat;1
# vertegenwoordigers;6
# gevraagd;11
# brandstofcompensatie;6
# taxichauffeurs;6
# boeren;6
# truckers;6
# boze;0
# voegen;11
# Zeebrugse;0
# trucks;6
# kilometers;6
# lang;0
# aanschoven;11
# blokkade;6
# havens;6
# Kanaaltunnel;6
# Fabian;6
# Lefevere;6
# Calais;6
# zegde;11
# compensatie;6
# brandstofprijs;6
# 2,30;7
# 14,26;7
# helft;6
# 1,30;7
# 8,06;7
# nieuws;0
# Zeebrugge;6
# waarheen;1
# schepen;6
# afgeleid;11
# file;6
# Geërgerde;11
# verbaal;0
# clinch;6
# Prompt;0
# Boulogne;6
# ,;6
# St-Malo;6
# Cherbourg;6
# Duinkerke;6
# ontruimd;11
# protesterende;11
# Enigszins;1
# verrassend;11
# amper;0
# dag;6
# Fabius;6
# sprake;6
# verlaging;6
# gegarandeerd;11
# verlaagde;11
# lasten;6
# verminderde;11
# havengelden;6
# toeziend;11
# blokkeerden;11
# grimmig;0
# Twaalf;7
# aanschuiven;6
# ferry;6
# pechstrook;6
# rechterrijvak;6
# Expressweg;6
# pikt;11
# slachtoffer;6
# puur;0
# Ondanks;8
# verzekerde;11
# bleven;11
# hoogtepunt;6
# Amper;1
# files;6
# Sommigen;9
# geblokkeerd;11
# kusthavens;6
# probeerden;11
# weg;6
# banen;11
# versperringen;6
# perken;6
# redelijke;0
# leiders;6
# Glavany;6
# heffen;11
# betogende;0
# politie.;6
# 's;2
# Ochtends;6
# klem;0
# raakten;11
# middag;6
# sein;6
# afgeblazen;11
# rederij;6
# P;7
# O-Stena;6
# hernam;11
# overtochten;6
# Dover;6
# Omdat;3
# tunnel;6
# verbinding;6
# sympathie;6
# Engelsen;0
# zoveelste;7
# rij;6
# Fransen;0
# toezegging;6
# wordende;11
# goedkoper;0
# havengelden;11
# bijdragen;6
# beneden;1
# haalde;11
# streep;6
# Actievoerders;6
# haven-;6
# Kanaaltunnel-blokkades;6
# medewerker;6
# akkoord;6
# bereikt;11
# Naar;3
# verluidt;11
# onderhandelingen;6
# stormachtig;0
# toegejuicht;11
# relaties;6
# allang;1
# hartelijk;0
# vissersbond;6
# André;6
# Fauchet;6
# bevestigen;11
# recentste;0
# criminaliteitscijfers;6
# spoorwegpolitie;6
# klokken;6
# 1.201;7
# diefstal;6
# bagage;6
# 241;7
# vandalisme;6
# 130;7
# arrestaties;6
# drugsbezit;6
# DVDB;6
# taken;6
# aanzienlijke;0
# februari;6
# aangiftebereidheid;6
# reizigers;6
# verhoogt;11
# Brussel-Zuid;6
# proberen;11
# toename;6
# zwartrijders;6
# daarom;3
# metrobrigade;11
# ondernomen;11
# traject;6
# Antwerpen-Brussel-Mons;6
# slagen;6
# verwondingen;6
# vaststellingen;6
# daarom;1
# feiten;6
# diefstallen;6
# station;6
# Pas;1
# hoor;11
# reist;11
# Vergeet;11
# bouwwerf;6
# uitnodigt;11
# crimineel;0
# Fonsnylaan;6
# Kuringen;6
# avonds;6
# uitmaakte;11
# 3.408;7
# 1.498;7
# pv's;6
# 364;6
# brigades;6
# patrouilles;6
# ernstige;0
# bedreigingen;6
# stations;6
# beslissen;11
# Hoezo;1
# criminaliteit;6
# fors;0
# toegenomen;11
# alarmerende;11
# berichten;6
# jongerenbende;6
# lijn;6
# Halle-Soignies;6
# Halle-Ath;6
# karakter;6
# unicum;6
# statistieken;6
# uitgesplitst;11
# Terug;1
# voordat;3
# plaatse;6
# afgesproken;11
# rijkswachtbrigades;6
# interventie;6
# Denkt;11
# verbale;0
# agressie;6
# Bouding;6
# mijnheer;6
# Schouppe;6
# verstaat;11
# drugsproblematiek;6
# nachttrein;6
# Amsterdam-Parijs;6
# nijpend;11
# grensoverschrijdende;0
# betrekkelijk;0
# aangiften;6
# schijnt;11
# vrees;6
# represailles;6
# gedelegeerd;11
# Etienne;6
# Opinie;6
# Criminaliteit;6
# verdubbeld;11
# beginperiode;0
# treinen;6
# teruggaan;11
# 1996;7
# betrouwbare;0
# Schouppe;0
# stoelen;6
# banken;6
# politionele;11
# voor;3
# bewakingsdienst;6
# binnenkort;1
# concreet;0
# actieplan;6
# bende;6
# klissen;11
# trein;6
# luchthaven;6
# Foto;6
# Filip;6
# Claus;6
# Denise;6
# den;2
# Broeck;6
# onderscheid;6
# algemeen;6
# '99;7
# 309;7
# 194;7
# tegenover;8
# spreekt;11
# toenemende;11
# treinbegeleiders;6
# Eerder;0
# Thillo;6
# geloofde;11
# succes;6
# bladen;6
# ...
# Marymount;6
# frustraties;6
# Burnett;6
# huizen;6
# schrikbarend;11
# arbeid;6
# crack;6
# raampje;6
# Chico;6
# tatoeages;6
# vandaan;1
# achteruit;1
# Nellie;6
# kapster;6
# gloeiende;11
# krultang;6
# kapsel;6
# betrekkingen;6
# groeiende;11
# gespannen;0
# Creative;6
# Hair;6
# Nails;6
# Design-zaak;6
# Boulevard;6
# aangekeken;11
# straalt;11
# spierballen;6
# stierennek;6
# tatoeëren;11
# kortgeschoren;11
# adjudanten;6
# kliederen;11
# graffiti;6
# moppert;11
# Ortega;6
# afkeer;6
# dwarsgezeten;11
# erbuiten;1
# schelen;11
# plukken;11
# pakten;11
# koffers;6
# kochten;11
# spotprijzen;6
# raam;6
# bordje;6
# opschrift;6
# Zwarte;0
# eigenaars;6
# uitbreken;11
# gespaard;11
# salvo;6
# "AK-47""";6
# Koreaanse;0
# verderop;1
# gesleept;11
# plekke;0
# herinnert;11
# geweer;6
# dak;6
# advocatenkantoor;6
# relschoppers;6
# mode;6
# aapt;11
# gebieden;6
# wijken;11
# Spanningen;6
# beruchtste;0
# Mexicanen;5
# verklaart;11
# gezag;6
# gevestigd;11
# Latijns-Amerikaans;0
# lantaarnpaal;6
# menu;6
# tacotent;6
# lunch;6
# frictie;6
# verkroppen;11
# profiteren;11
# decennialang;0
# gestreden;11
# gerespecteerd;11
# lucratieve;0
# wijkbestuur;6
# ondernemers;6
# gebroken;11
# griezelig;0
# aangeslagen;11
# winkels;6
# plat;0
# branden;11
# logo;6
# Trots;0
# stapt;11
# Lexus;6
# postuum;6
# portret;6
# getuigenissen;6
# Buckley's;6
# vriendinnen;6
# muzikanten;6
# gitarist;6
# Tighe;6
# politieagente;6
# Jeffs;6
# lijk;6
# opviste;11
# zijarm;6
# Mississippi;6
# eigenares;6
# New;0
# Yorkse;0
# Fez-club;6
# optrad;11
# Guibert;6
# nagedachtenis;6
# gedirigeerde;0
# hilarische;0
# homevideo's;6
# fotografe;0
# Merri;6
# Cyr;6
# Jeff;6
# Buckley;6
# tournees;6
# langspelers;6
# Sketches;6
# My;6
# Sweetheart;6
# Drunk;5
# Mystery;6
# White;6
# Boy;6
# uitgekomen;11
# video;6
# dvd;6
# Chicago;6
# verdronken;11
# zanger;6
# komst;6
# poëtisch;0
# aandoet;11
# gedichten;6
# fotomontages;6
# hommagesong;6
# gezongen;11
# Stef;6
# Kamil;6
# Carlens;6
# Zita;6
# Swoon;6
# Radiohead;6
# laddism;6
# omschreef;11
# levensstijl;6
# gesymboliseerd;11
# britpopbands;0
# Oasis;6
# Grape;6
# gepaard;11
# vecht-;6
# bralpartijen;6
# voetbalhooliganisme;6
# drinken;11
# interviews;6
# humoristische;0
# grootmoedige;0
# persoonlijkheid;6
# warhoofd;6
# beetje;6
# regelen;11
# aftastende;11
# frasering;6
# dwalende;11
# soepele;0
# bands;6
# Muse;6
# Arid;6
# Geneva;6
# Prayer;6
# Boat;6
# voorbijgegaan;11
# 28ste;7
# bezweek;11
# negental;6
# platen;6
# nagelaten;11
# journaliste;6
# NRC;6
# Handelsblad;6
# Fekovic;6
# geconditioneerd;11
# gekneed;6
# vervangmiddel;6
# weggelopen;11
# trachtte;11
# ironie;6
# pas;6
# herdenkingsplechtigheid;6
# Tims;6
# liedjes;6
# gehore;0
# Jasmina;6
# Fekovics;6
# berekendere;0
# omging;11
# begaan;11
# filmde;11
# geruime;0
# woonde;11
# Memphis;6
# sleet;0
# maakster;6
# verwijst;11
# afstudeerproject;6
# afscheid;6
# rockmuziek;6
# passie;6
# poëzie;6
# emotionaliteit;6
# nuance;6
# geringe;0
# jr.;0
# Goodbye;0
# and;5
# Hello;5
# wordt;5
# VPRO;6
# filmdagen;6
# Utrecht;6
# wedijveren;11
# gekend;11
# cultfiguur;6
# platenverkoop;6
# scheidt;11
# vroegtijdige;0
# dood;6
# halfgod;6
# filmdocumentaire;6
# ontleent;11
# doorgaf;11
# Goodbye;6
# was;5
# eindwerk;6
# filmacademie;6
# bezegelde;11
# Nighttown;6
# Rotterdam;6
# Buckley-herdenkingsdag;6
# overlijden;11
# Man;6
# geschrokken;11
# pogingen;6
# evenveel;7
# onthaald;11
# werden.;6
# fijntjes;1
# machtsstructuren;6
# gedifferentieerde;11
# rijk;0
# formuleren;11
# verantwoording;6
# arbeidsvreugde;6
# ministerschap;6
# uitstapregeling;6
# 55;7
# onderwijsfuncties;6
# behoren;11
# 11-julitoespraak;7
# pleitte;11
# ontzuiling;6
# Vandenbroucke;6
# niet-vakbondsleden;6
# oppositie;6
# tijde;6
# opener;0
# show;6
# arbeidsovereenkomst;6
# clash;6
# onderwijsbonden;6
# partijvoorzitter;6
# onderwijspensioenen;6
# elektriciens;6
# loodgieters;6
# coiffeurs;6
# loodzware;0
# inloopjaar;6
# degene;9
# uitzetten;11
# flexibeler;6
# Eigenlijk;0
# straffen;11
# bonden;6
# verzekeren;11
# KTA;6
# Deurne;6
# CVP-onderwijsspecialist;6
# bijdragen;11
# beroepen;6
# accenten;6
# gezeten;11
# kondigden;11
# betogen;6
# invullen;11
# inbouwen;11
# misloopt;11
# Trouwens;4
# voltallige;0
# vertegenwoordigen;11
# Woensdag;6
# COC;6
# COV;6
# serene;0
# aangaan;11
# gepresteerd;11
# eis;6
# nettenvervaging;6
# Lees;11
# Klopt;6
# Syndicale;6
# verkennende;11
# betwijfel;11
# jaloers;0
# herdacht;11
# zinvolle;0
# lineaire;0
# onrechtvaardig;0
# tegendeel;6
# VLD-vrouw;6
# slalommen;11
# kanonschoten;6
# afvuurden;6
# rolt;11
# rode;0
# blauwe;0
# loper;6
# Antoon;6
# Boone;6
# Maken;11
# CAO;6
# invulling;6
# loontevredenheid;6
# ernstig;0
# chantagetechnieken;6
# machtig;0
# aankondigt;11
# syndicale;0
# 55-plussers;6
# uitstapsysteem;6
# zuinigjes;6
# telefoontje;6
# waarnemend;0
# betoging;6
# aangezegd;11
# 31.000;7
# bevraagde;11
# woog;11
# takenpakket;6
# PMS'en;6
# MST's;6
# transparantere;0
# schooltoezicht;6
# bezinnen;11
# sneerde;11
# begeleidende;11
# schaalvergroting;6
# kwijtgespeeld;11
# doorbreken;11
# kindgericht;11
# reorganisatie;6
# werkgeheel;6
# Catoire;6
# sommigen;9
# CLB's;6
# leerlingenbegeleiding;6
# consequent;0
# wenken;6
# bediend;11
# werkveld;6
# wrevel;6
# behield;11
# fusie;6
# Vernieuwde;11
# spitsen;11
# mensenmaat;6
# sociaal-emotionele;0
# schoolloopbaanbegeleiding;6
# leerproblemen;6
# aanvoelen;11
# klantgericht;6
# werkcultuur;6
# Wereldschokkend;1
# Danielle;6
# mandaathoudster-directrice;6
# Cattoir;6
# gesleuteld;11
# psycho-medisch-sociale;0
# klassieke;0
# bevroren;11
# ondergaan;11
# heet;11
# klantgericht;11
# consumentenmagazine;11
# hierin;1
# gespecialiseerd;11
# competentie;6
# gevoelig;0
# werkten;11
# opgericht;11
# doorslaggevende;0
# doorwegen;11
# expertise;6
# grootstedelijke;0
# dyslexie;6
# autisme;6
# competenties;6
# stroomlijnen;11
# Huilende;11
# krampachtig;0
# vastklampen;11
# vertrouwde;0
# thuisomgeving;6
# ontlopen;11
# huilen;11
# schreipartijen;6
# afspelen;11
# Schoolfobie;6
# paniek;6
# overvallen;11
# voorspelbare;0
# taferelen;6
# ingewikkeld;0
# Stellamans;6
# psychologisch;0
# therapie;6
# overmand;11
# klaslokaal;6
# belandt;11
# veelal;1
# kinderpsycholoog;6
# dieper;0
# uitmondt;11
# regelrechte;0
# paniekaanvallen;6
# dekt;11
# Absoluut;0
# Zoiets;9
# ontwikkeling;6
# 95;7
# grip;6
# emoties;6
# huishouden;6
# benoemen;11
# overstappen;11
# angstig;0
# zelfstandigheid;6
# Stellamans;1
# vertaalt;11
# aanklampingsgedrag;11
# mama;6
# wenen;11
# niks;9
# vordert;11
# depressief;6
# Eerst;1
# schoolbel;6
# toegedekt;11
# schoolfobie;6
# duikt;11
# hevige;0
# afbakenen;6
# kinderpsychologe;0
# Hedwige;6
# alleenrecht;6
# moeilijkere;0
# veralgemenen;11
# thuissituatie;6
# Normaal;0
# kinderpsychologen;6
# Elke;9
# verschillend;11
# uitdrukt;11
# waakzaam;0
# blokletters;6
# gezwicht;11
# achterblijven;11
# Bereikbaarheid;6
# Callebert;6
# CGGZ-team;6
# gekoesterd;11
# verlangen;6
# verzorgen;11
# desondanks;1
# contra's;6
# Kinderpsychologen;6
# boudweg;1
# gsm's;6
# navelstreng;6
# vals;0
# verbondenheid;6
# onzichtbare;0
# hebbeding;11
# begeerd;11
# standaarduitrusting;6
# scholier;6
# schoolmuren;6
# beheren;11
# hoe;6
# Immoreel;6
# plekken;6
# populariteit;6
# gadget;6
# waanzinnige;0
# smaak;6
# Nogal;6
# geïrriteerd;11
# midden;6
# exposé;6
# rinkelen;11
# intrede;6
# ondervonden;11
# afzetten;11
# begrensd;11
# onbereikbaarheid;6
# fabrikant;6
# Ericsson;6
# ontwerpt;11
# peuters;6
# toetsen;6
# Neem;11
# beurtelings;1
# verblijft;11
# bereikbaar;0
# persoonlijkheidsontwikkeling;6
# stremmen;11
# bediscussieerd;11
# rage;6
# overgewaaid;6
# nuttige;0
# Jacques;6
# Cochez;6
# psychotherapeut;6
# Medisch;6
# Opvoedkundig;6
# kanten;6
# Gsm's;6
# opgedrongen;11
# overbezorgde;0
# telg;6
# Kinderpsychologe;0
# regelrecht;0
# zeulen;11
# allerkleinsten;0
# mobieltje;6
# boekentas;6
# instructief;0
# adagium;6
# strikt;0
# volop;1
# gsm-series;6
# mikken;11
# uitbreiding;6
# telefoons;6
# ontbijttafel;6
# bereikbaarheid;11
# expert;6
# categorisch;0
# afwijzing;6
# fotootje;6
# knoppen;6
# geplakt;11
# Flauwekul;6
# producenten;6
# gelegen;11
# bezwaren;6
# inburgeren;11
# excuus;6
# ingewikkeldheid;6
# weggewerkt;11
# apparaat;6
# sinterklaasperiode;11
# kleurige;0
# beltonen;6
# pakweg;6
# twaalfjarige;0
# uithangt;11
# Orfee;6
# Geestelijke;6
# Gezondheidszorg;6
# CGGZ;6
# huivert;11
# Hoogst;0
# bedenkelijk;0
# aids;0
# Afrikaans;0
# Tijl;6
# Jonckheer;6
# ziekte;6
# multidisciplinaire;0
# medicatie;0
# mondiale;0
# aids-epidemie;6
# doorzet;11
# immense;0
# ineenstorting;6
# overmeesteren;11
# besmette;0
# leeft;11
# kinderarts;6
# geneesheer-coördinator;6
# seropositieve;0
# Koningin;6
# Paola;6
# Kinderziekenhuis;6
# Prioritair;6
# schandalige;0
# armoede;6
# GOS;6
# baart;11
# Aids;6
# Storm;6
# India;6
# telt;11
# Afrika;6
# 0,7;7
# besmet;11
# 4.000.000;7
# westerse;0
# voorzover;3
# aidsprobleem;6
# medicatie;6
# seropositieve;9
# Azië;6
# Cambodja;6
# Epidemie;6
# wereldvrede;6
# oplossingen;6
# holocaust;6
# killing;6
# fields;1
# genocide;6
# Rwanda;6
# horror;6
# overtreffen;11
# ineengestort;6
# prooi;6
# krijgsheren;6
# rijkdommen;6
# bodem;6
# leegplunderen;11
# indien;3
# behandeling;6
# 22.000;7
# 44.000;7
# overgedragen;11
# onbeschermd;0
# besmette;11
# naalden;6
# druggebruikers;6
# genezen;11
# vaccin;6
# patiënten;6
# optimisme;6
# instorten;11
# gewapende;11
# gezondheidszorgvoorzieningen;6
# prostitutie;6
# intraveneus;0
# druggebruik;6
# tuberculose;6
# explosieve;0
# cocktail;6
# HIV;6
# virus;6
# overdragen;11
# inkomen;6
# realistisch;0
# reduceren;11
# farmaceutische;0
# firma's;6
# aidsremmende;11
# wereldbevolking;6
# HIV-virus;6
# catastrofaal;0
# VN-Veiligheidsraad;6
# oppassen;11
# toepasbaar;0
# Marshall-plan;6
# ontketenen;11
# 0,7-procentsnorm;6
# respecteren;11
# kreet;6
# pleidooi;6
# sub-Saharisch;0
# instappen;11
# partenariaten;6
# voortouw;6
# Botswana;6
# overgaat;11
# doeltreffende;0
# antiretrovirale;0
# volksgezondheid;6
# opgebruikt;11
# niet-besmette;0
# elementaire;0
# curatieve;0
# Westen;6
# aartsgevaarlijke;0
# Bravo;6
# medicaties;6
# vereenvoudigde;11
# schema's;6
# levensverwachting;6
# Middeleeuwen;6
# kwijtschelden;11
# schulden;6
# wapenembargo;6
# gedemilitariseerd;11
# vrijgekomen;11
# financieren;11
# medicamenten;6
# aids-probleem;6
# oplossen;11
# Zuid-Amerika;6
# Centraal-Amerika;6
# Caraïben;6
# percentages;6
# 0,5;7
# pre-epidemische;0
# voorbode;11
# Zuid-Afrikaanse;0
# seropositieven;6
# kampen;6
# Slaap;11
# Zuid-Afrika;6
# telde;11
# 3.400.000;7
# 5.000.000;7
# Zimbabwe;6
# nú;6
# epidemie;6
# aids;6
# ware;0
# boodschappen;6
# socio-economisch;0
# onvervangbaar;0
# bedreigt;11
# Piot;6
# UNAIDS;6
# slaappillen;6
# Yamaha;6
# XP;6
# Tmax;6
# diamondkader;6
# remmen;6
# scooter;6
# reuzebenieuwd;11
# testen;11
# comfortabele;0
# pk'er;6
# scooter-tweecilinder;6
# watergekoeld;11
# YP;6
# Majesty;6
# merk;6
# Suzuki;6
# cc'er;6
# toon;6
# vermogensvolle;11
# LW;6
# wegligging;6
# Naar;8
# Yamaha;4
# modellen;6
# 125;7
# cc'ers;6
# autosnelwegen;6
# vermogensgebrek;6
# vanzelfsprekend;0
# motorfietsen;6
# vering;6
# aangepakt;11
# wielen;6
# inches;6
# Weenen;6
# topsnelheid;6
# begroot;11
# 160;7
# Om;8
# rijwielgedeelte;0
# tentoonstellingsruimte;11
# exposanten;6
# Tel;6
# 00.49.89.9.49.1.16.08;7
# motor-;6
# scooterbeurs;6
# Ifma;6
# plaatshad;11
# Intermot;6
# tweejaarlijks;1
# toonaangevend;0
# Adres;6
# Messe;6
# Messegelände;6
# liefhebbers;6
# geduld;11
# aluminium;6
# cockpitstructuur;6
# bodemplaten;6
# composietmateriaal;6
# Cadillac-roadster;6
# juwelier;6
# Bulgari;6
# interieur;6
# aankleden;11
# Wacht;11
# Detroit;6
# AD;6
# GM-dochter;6
# werelds;6
# indrukwekkendste;0
# coupés;6
# cabrio's;6
# bouwde;11
# bekoren;11
# Cadillac;6
# mikt;11
# gefortuneerde;11
# fabriek;6
# serieproductie;6
# Alain;6
# Devos;6
# naamloze;0
# bolide;6
# prototype;6
# getoonde;11
# Evoq;6
# Allanté;6
# dramatische;0
# flop;6
# elegante;0
# Seville;6
# berlines;6
# Mercedes;6
# BMW;6
# Jaguar;6
# elektrisch;0
# simpele;0
# knop;6
# openen;11
# herleven;11
# aandrijving;6
# achterwielen;6
# variant;6
# V8-Northstar-motor;6
# stoffen;6
# Car;6
# Top;6
# Systems;6
# ontworpen;11
# hardtop;6
# constructeur;6
# spectaculaire;0
# roadster;6
# uitbrengen;11
# SL;6
# krachtbron;6
# versnellingsbak;6
# wielophanging;6
# comfort;6
# stabilisatorstang;6
# achteras;6
# bochten;6
# loodst;11
# houdend;11
# 1.132.997;7
# 28.086;7
# logisch;0
# invoerders;6
# gamma;6
# voorwielen;6
# 3-liter-V6;7
# kleppen;6
# cilinder;6
# 177;7
# pk;6
# koppel;0
# 271;7
# newtonmeter;6
# Ford;6
# Taurus;6
# thuismarkt;6
# populairste;0
# streken;6
# Hessing;6
# heleboel;6
# Fords;6
# verdeelt;11
# verkrijgbaar;0
# topper;6
# verstelbare;0
# leder;6
# beklede;11
# airconditioning;6
# snelheidsregelaar;6
# muziekinstallatie;6
# cd-wisselaar;6
# luxueus;0
# steviger;0
# veiliger;0
# crashtests;6
# five;0
# rating;6
# opleverde;11
# nieuwigheid;6
# Echt;0
# semi-cabrio;6
# Lotus;6
# Elise;6
# onderstel;6
# overneemt;11
# leuke;0
# vingeroefening;6
# Opel;6
# Genève;6
# Speedster;6
# koop;6
# spartaans;0
# kilo's;6
# uitgespaard;11
# koetswerk;6
# Opel-ontwerp;6
# motor;6
# 900;7
# pakweg;8
# Mazda;6
# MX5;6
# Toyota;6
# herleide;11
# sportwagen;6
# enthousiast;0
# Astra;6
# Coupé;6
# 2,2-liter;6
# 147;7
# 1,2;7
# neertellen;11
# Hethel;6
# Alsof;3
# Zeg;11
# afmetingen;6
# Elektrische;0
# impulsen;6
# schakelintenties;6
# achterzetels;6
# neergeklapt;11
# laadruimte;6
# ruit;6
# doorzichtig;0
# klantenbestand;11
# vervrouwelijken;6
# verjongen;6
# volstaat;6
# pook;6
# eventjes;6
# tikken;11
# ontkoppelt;11
# schakelt;11
# koppelt;11
# 2-liters;6
# vermogens;6
# 129;7
# 163;7
# 2,3-liter;6
# 197;7
# 2,2-liter-CDI-diesel;6
# 143;7
# korter;0
# berline;6
# flashy;5
# Volledig;0
# evengoed;1
# afgeleide;11
# sportcoupé;6
# dynamische;0
# C-klasse;0
# was;6
# 3-serie;0
# twijfelen;11
# rijplezier;6
# brandstofverbruik;6
# krachtbronnen;6
# SLK;6
# Origineel;6
# spoiler;6
# onderaan;8
# achterruit;6
# supplement;6
# verkrijgbare;0
# panoramische;0
# schuifdak;6
# voorruit;6
# achterspoiler;6
# Groter;6
# Sequentronic-transmissie;6
# Zonneschermen;6
# opwarmt;11
# A-klasse;0
# geautomatiseerde;11
# zesversnellingsbak;6
# mechanische;0
# verbindingselementen;6
# koppelingspedaal;6
# Prijzen;6
# kunstenaar;6
# bedwong;6
# vormidee;6
# kies;11
# steenbrok;6
# steengroeve;0
# Lemay;6
# Doornik;6
# overrompelende;11
# chaotische;0
# stenen;6
# hunkeren;11
# verliefde;0
# pubers;6
# ritmiek;6
# positionering;6
# bewerkte;11
# oppervlak;6
# bindt;11
# getal;6
# teken;11
# Doornikse;0
# Stichting;6
# Grard;6
# Parmentier;6
# conceptueel;0
# gegaan;11
# expositie;6
# aangegrepen;11
# wordingsproces;6
# sculpturen;6
# doeken;6
# geplaatste;11
# tussenruimte;0
# Gijverinkhove;1
# Even;1
# Toegangsprijs;6
# karakteristieken;6
# bewerking;6
# studiewerk;6
# geregelde;0
# tussenpozen;6
# geologie;6
# kleur;6
# Al;9
# Westhoekse;0
# Gijverinkhove;6
# ongepolijste;11
# basale;0
# vormen;6
# bronzen;0
# vrouwenlichamen;6
# beeldhouwer;6
# 1901;7
# 1984;7
# uitzoeken;11
# bruikbaar;0
# lichamelijkheid;6
# sensualiteit;6
# huid;6
# ritmische;0
# structuren;6
# monumentaliteit;6
# Bracke;6
# compositie;6
# globale;0
# aanblik;6
# hardsteen;6
# Soignies;6
# Balegemse;0
# ingrepen;6
# gipsvormen;6
# bekijk;0
# Wonderlijk;0
# rijmen;11
# hoekige;0
# 1952;7
# bevallige;0
# artefact;6
# foto's;6
# tekeningen;6
# indrukwekkende;0
# EB;6
# Beelden;6
# Vormen;11
# contourlijnen;6
# kleurgradaties;6
# houtskool;6
# olieverf;6
# hoef;11
# langdurig;0
# natuurlijkheid;6
# Observaties;6
# Noord-Franse;0
# kusten;6
# kliffen;6
# Audresselles;6
# doordachte;0
# beeldenweide;6
# samenhangend;11
# ensemble;6
# beschouwt;11
# Eenmaal;1
# handelbare;0
# gekliefd;11
# boorgaten;6
# gelaten;11
# atelier;6
# wellen;11
# groeve;6
# uitkies;6
# ruwe;0
# bewerk;6
# Ontmoeting;6
# Grard-Johan;6
# Parmentier;3
# Ekestraat;6
# 8691;7
# Gijverinkhove;0
# verhoudingen;6
# organische;0
# lichamen;6
# centimeters;6
# millimeters;6
# mist;6
# plooi;11
# tekenwerk;6
# bezinken;11
# geheugen;6
# veringreacties;6
# koppel;6
# '98-model;6
# 4.000;7
# toeren;6
# minuut;6
# onderin;1
# Kawasaki;6
# ZX;7
# 9R;7
# 469.950;7
# 11.649,76;7
# hap;6
# viercilinder;6
# snelheden;6
# verstandig;0
# Kawa;6
# vermoeide;11
# polsen;6
# voorrem;6
# doseren;11
# noodsituaties;6
# ABS-systeem;6
# insturen;11
# probleemloos;6
# vermogensexplosie;6
# achtergedeelte;6
# gedemonteerd;11
# leeggewicht;6
# 186;7
# wendbaarheid;6
# motorfiets;6
# verlichting;6
# ZX;6
# 9;6
# agressiever;0
# voorganger;6
# Erg;0
# versnellingen;6
# voortrein;6
# functioneert;11
# voorbeeldig;0
# wegdek;6
# sensatie;6
# sporter;6
# adres;6
# bevredigend;11
# zitpositie;6
# lengte;6
# ritten;6
# overdrijft;11
# passagier;6
# voetsteunen;6
# afwerking;6
# sportieve;0
# temperamentvol;0
# dier;6
# inbinden;11
# 140;7
# 275;7
# gezwind;11
# stadsverkeer;6
# versie;6
# rondingen;6
# wettige;0
# aanhouden;11
# sparen;11
# vermits;3
# 5.000;7
# teller;6
# prikt;11
# Achteraan;6
# regelbaar;0
# Ninja;6
# overheerste;11
# verbruik;6
# voortreffelijke;0
# achtervelg;6
# bekomen;11
# verstand;6
# modelversie;6
# hobbelig;0
# ophanging;6
# Doordat;3
# afgezien;11
# polyvalenter;6
# koplampen;6
# Peugeot;6
# Citroën;6
# Renault;6
# goedmaken;11
# Logisch;0
# motoren;6
# HDI;6
# zuster;6
# dCi;6
# laatstgenoemde;0
# 1,9-liter-dCi;6
# 105;7
# maximumkoppel;6
# 1.500;7
# rendement;6
# turbodiesels;6
# presteerden;11
# zuiniger;0
# omsprongen;6
# brandstof;6
# 1.350;7
# bar;6
# bedragen;11
# verneveling;6
# homogenere;0
# vermenging;6
# toelaat;11
# afgewacht;11
# Scénic;6
# dieselmotor;6
# RX4;7
# meten;11
# TDI's;6
# Audi;6
# JTD's;6
# CDI's;6
# diesels;6
# indirect;0
# ingespoten;11
# voorbijgestreefde;11
# zelfontbranders;6
# leeg;0
# anderhalve;7
# ton;6
# wegende;11
# volstaat;11
# mirakels;6
# Laguna;6
# aangedreven;11
# terreinwagen;6
# uitgedoste;11
# 950.000;7
# 23.550;7
# 2-literbenzinemotor;6
# volledigere;0
# verbranding;6
# uitstoot;6
# schadelijke;0
# enkel;6
# vermindering;6
# lawaai;6
# trillingen;6
# voorinspuiting;6
# verbrandingskamer;6
# progressief;0
# brutaal;0
# drieletterwoord;6
# injectie;6
# common;6
# rail;6
# verdeelbuis;6
# brandstofdruk;6
# gehandhaafd;11
# toerental;6
# Gedurende;8
# constructeurs;6
# dieselspecialisten;6
# Passat;6
# Europa's;6
# middenklasser;6
# 193;7
# krachtigste;0
# benzinemotor;6
# Esthetisch;0
# detail;6
# achtersteven;6
# hertekend;11
# uitvoeringen;6
# chroom;6
# Volkswagen;6
# lente;6
# 300;7
# achtcilinder;6
# limousine;6
# wapenen;11
# C5;6
# Mondeo;6
# achterlichten;6
# exclusiever;6

# %% [markdown]
# ### Training

# %%
epochs = 5
for e in range(epochs):
    for inp, targ in zip(tokens_tr , targets_tr):
        inp = inp.lower()
        if inp in embeddings_model:
            embedding = embeddings_model[inp]
            nn.train(embedding, targ) 
        else:
            pass

# %% [markdown]
# ### Testing

# %%
scorecard = []
predicted_labels = []
selected_targets = []
#predicted_labels = []
for inp, targ in zip(tokens_te, targets_te):
    inp = inp.lower()
    try: 
        embedding = embeddings_model[inp]
        
        # query network 
        outputs = nn.query(embedding)

        # highest number == label 
        label = np.argmax(outputs)
        predicted_labels.append(label)
        selected_targets.append(targ.index(max(targ)))

        # append correct / incorrect to scorecard 
        #print(targ.index(max(targ)))
        if label == targ.index(max(targ)):
            scorecard.append(1)
        else:
            scorecard.append(0)
            
    except: 
        pass

    
scorecard_array = np.asarray(scorecard)
print(f"performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# []
# performance =  nan
# <ipython-input-12-5e99de79c4bc>:30: RuntimeWarning: invalid value encountered in double_scalars
#   print(f"performance = ", scorecard_array.sum() / scorecard_array.size)

# %% [markdown]
# ### Evaluation

# %%
# Find out the labels that are present (optional)
target_set = set()
for num in selected_targets:
    target_set.add(num)
print(target_set)
# Out:
# {0, 1, 2, 3, 6, 8, 9, 11}

# %%
# print confustion matrix 
cm = confusion_matrix(selected_targets, predicted_labels)
df_confusion = pd.DataFrame.from_records(cm)
#print(df_confusion)
print(df_confusion.to_latex())
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
# {} &  0 &  1 &  2 &  3 &   4 &   5 &  6 &  7 \\
# \midrule
# 0 &  1 &  0 &  0 &  0 &   2 &   0 &  0 &  4 \\
# 1 &  0 &  7 &  0 &  0 &   0 &   0 &  0 &  1 \\
# 2 &  0 &  0 &  8 &  0 &   0 &   0 &  0 &  0 \\
# 3 &  0 &  2 &  0 &  3 &   0 &   3 &  0 &  0 \\
# 4 &  0 &  0 &  0 &  0 &  29 &   0 &  0 &  0 \\
# 5 &  0 &  0 &  0 &  0 &   0 &  10 &  0 &  0 \\
# 6 &  1 &  0 &  0 &  3 &   0 &   0 &  3 &  1 \\
# 7 &  0 &  0 &  0 &  0 &   1 &   0 &  0 &  7 \\
# \bottomrule
# \end{tabular}
